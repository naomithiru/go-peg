# %% [markdown]
# # NETWORKS TRANSFORMATION
#
# This notebook contains all the functions needed to perform various trasformations to the networks of the tracing usecase, and prepare the data for harmonization.
#
# Datasets Needed:
#
# - Hydro-network dataset
# - Sewer network dataset / Discharge Points dataset

# %% [markdown]
# ## Expected Outputs
#
# - Connection nodes
# - Discharge points
# - Start and end nodes for water
# - Water dataset with start and end ID
# - Split water dataset with new start and end ids
# - Fully connected water dataset

# %%
import os
import sys
path = os.path.dirname(os.path.abspath(''))
os.chdir(path)
print(path)
sys.path.insert(0, path)
# Out:
# c:\Workdir\Develop\repository\go-peg

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, LineString, MultiPoint, MultiLineString
from shapely import wkt
from shapely.ops import nearest_points
import shapely.wkt
import numpy as np

import random


import warnings
from shapely.errors import ShapelyDeprecationWarning
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning)
pd.options.mode.chained_assignment = None  # default='warn'


from config import config

# %%
# from src.config import funcs

# %% [markdown]
# ## 1. Prepare Water Network
# A water network is received as an edge only network wih no nodes. Here, we generate hydro-nodes from the begining and end points of a linestring geometry, and assign them unique ids that can then be added to the water segments as begin and end points.
#
# The following steps are performed:

# %% [markdown]
# ### 1.1. CRS
# Assign the coordinate reference system as a global variable to use through out the application.

# %%
PROJ_CRS = "EPSG:31370"

# %% [markdown]
# ### 1.2. Load Water Data
# Load the data into a dataframe. Various formats can be loaded onto a dataframe in Geopandas. Here, both shapefiles and GML data are used.
#
# Set the crs to the project crs.

# %%
def load_data(path, PROJ_CRS):
    """
    Loads the data from the given path,
    and prints the shape and crs of the data.
    """
    data = gpd.read_file(path)
    print(data.shape)
    #print("Original crs:", data.crs)
    data = data.to_crs(PROJ_CRS)
    print("Project crs:", data.crs)
    data = data.drop_duplicates(subset=["geometry"]).reset_index(drop=True)
    return data


path = config.data_src / "flanders_hydro_network/Wlas.shp"

water_data = load_data(path, PROJ_CRS)
# Out:
# (63767, 19)
# Project crs: EPSG:31370

# %% [markdown]
# ### 1.3. Turn multiline water network into single line water network
#
# The water segments geometries can sometimes be stored as a multilinestring. This means that the geometries are represented by nested lists and this can make programmatically manipulating them difficult. Therefore multiline water networks are converted into single line water networks by splitting the linestrings into individual linestrings. This is done by 'flattening' the nested list that makes up a multilinestring structure.
#
# This ensures we can extract begin and end points of a water segment.

# %%
# Check for multiline strings in a dataset
def check_multiline(df):
    """This function checks for multiline strings
    from the geometry column in a given dataset"""
    lst = df["geometry"].to_list()
    multiline_count = 0
    for item in lst:
        if isinstance(item, MultiLineString):
            multiline_count += 1
    print("MultiLinesStrings:", multiline_count)


def multiline_to_linestring(df, geom_col):
    # multiline_count = check_multiline(df)
    # if multiline_count == 0:
    #     return df
    # else:
    linestrings = []
    for idx, row in df.iterrows():
        if isinstance(row['geometry'], LineString):  
            linestrings.append(row['geometry'])
        elif isinstance(row['geometry'], MultiLineString):
            geoms = [i for i in row['geometry'].geoms]
            outcoords = [list(item.coords) for item in geoms]
            outline = shapely.geometry.LineString([i for sublist in outcoords for i in sublist])
            linestrings.append(outline)
    df['geometry'] = linestrings
    print("Checking for multiline strings after...")
    check_multiline(df)
     # multiline_count = check_multiline(df)
    assert len(linestrings) == len(df)
    return df

# %%
water_data = multiline_to_linestring(water_data, 'geometry')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 water_data = multiline_to_linestring(water_data, 'geometry')
#
# NameError: name 'water_data' is not defined

# %% [markdown]
# ### 1.4. Generate begin and end nodes
#
# Get begin and end point geometries by extracting the first and the last point geometries of a linestring.

# %%
def add_beginpoints(df):
    startnodes_gdf = df.copy()
    lst = startnodes_gdf["geometry"].to_list()
    beginpoints = []
    for item in lst:
        first = Point(item.coords[0])
        first_precise = shapely.wkt.dumps(first)
        beginpoints.append(first_precise)

    startnodes_gdf["start_point"] = [wkt.loads(g) for g in beginpoints]
    startnodes_gdf = startnodes_gdf.drop(["geometry"], axis=1).rename(
        columns={"start_point": "geometry"}
    )

    startnodes_gdf = gpd.GeoDataFrame(
        startnodes_gdf, geometry=startnodes_gdf["geometry"], crs=PROJ_CRS
    )  # .drop(columns=[col])
    return startnodes_gdf


def add_endpoints(df):
    endnodes_gdf = df.copy()
    lst = endnodes_gdf["geometry"].to_list()
    endpoints = []
    for item in lst:
        last = Point(item.coords[-1])
        last_precise = shapely.wkt.dumps(last)
        endpoints.append(last_precise)

    endnodes_gdf["end_point"] = [wkt.loads(g) for g in endpoints]
    endnodes_gdf = endnodes_gdf.drop(["geometry"], axis=1).rename(
        columns={"end_point": "geometry"}
    )

    endnodes_gdf = gpd.GeoDataFrame(
        endnodes_gdf, geometry=endnodes_gdf["geometry"], crs=PROJ_CRS
    )  # .drop(columns=[col])
    return endnodes_gdf

# %%
startnodes_gdf = add_beginpoints(water_data)
endnodes_gdf = add_endpoints(water_data)

# %% [markdown]
# #### Note 1:
# Assert statements are used to test if the results generated are the expected results

# %%
assert startnodes_gdf.shape == endnodes_gdf.shape

# %% [markdown]
# ### 1.5. Document the nodes
#
# After the nodes have been created, perform spatial join the startnodes and endnodes dataframes to create one nodes geometry.

# %%
def get_nodes(id_col, region):
    nodes_geom = pd.merge(
        startnodes_gdf[[id_col, "geometry"]],
        endnodes_gdf[[id_col, "geometry"]],
        on="geometry",
        how="outer",
    ).reset_index(drop=True)
    unique_id_df = (
        nodes_geom[["geometry"]].drop_duplicates().reset_index().drop(columns=["index"])
    )
    assert len(unique_id_df) == nodes_geom.geometry.nunique()

    unique_id_df["New_ID"] = range(1, len(unique_id_df) + 1)
    unique_id_df["node_id"] = (region + '_HN') + unique_id_df["New_ID"].astype(str)
    gdf = gpd.GeoDataFrame(
        unique_id_df, geometry=unique_id_df["geometry"], crs=PROJ_CRS
    ).drop(columns=["New_ID"])
    return gdf

# %%
water_nodes_df = get_nodes("VHAS", "VL")
assert len(water_nodes_df) == water_nodes_df.geometry.nunique()

# %%
water_nodes_df.sample(5)
# Out:
#                             geometry     node_id
# 4366   POINT (119985.935 203401.895)   VL_HN4367
# 46568  POINT (233723.400 207993.233)  VL_HN46569
# 23283  POINT (187961.047 214322.640)  VL_HN23284
# 54511   POINT (86579.294 210403.255)  VL_HN54512
# 47946  POINT (101552.117 191962.212)  VL_HN47947

# %% [markdown]
# ### 1.6. Add the nodes to water segments, and create start and end id columns
#
# Using the sjoin method, map the nodes onto the linestrings to identify water segment start nodes and end nodes. Label nodes as either start_id or end_id in the water dataframe.

# %%
def add_ids_to_edges():
    # Label nodes as either start_id or end_id
    startnodes_merged = (
        gpd.sjoin(startnodes_gdf, water_nodes_df, how="left")
        .rename(columns={"node_id": "start_ID"})
        .drop("index_right", axis=1)
    )
    endnodes_merged = (
        gpd.sjoin(endnodes_gdf, water_nodes_df, how="left")
        .rename(columns={"node_id": "end_ID"})
        .drop("index_right", axis=1)
    )

    nodes_geom = pd.merge(startnodes_merged, endnodes_merged, on="VHAS")

    nodes = nodes_geom[["VHAS", "start_ID", "end_ID"]]

    water_edges_nodes = pd.merge(
        water_data, nodes, left_on="VHAS", right_on="VHAS"
    )  # .drop('id', axis=1)
    return water_edges_nodes


water_final = add_ids_to_edges()
assert water_final.VHAS.nunique() == water_final.geometry.nunique()

# %%
# water_final.to_file(r"data_transform\\vl_water_edges.shp")
#![2.water_nodes.PNG](attachment:2.water_nodes.PNG)

# %% [markdown]
# ## 2. Prepare Sewer Network
#
# Load the sewer network edges and nodes files.
# If there is no sewer network, then load discharge points.

# %% [markdown]
# In this example dataset, the sewer network dataset consists of both nodes and edges.
#
# Some networks will contain only nodes(discharge points). This scenario can also work as explained a few steps further
#
# STRENG
# - Definition: A string is the modeling of a part of a sewer with fixed properties. Strands are linked together by coupling points, creating a network of strands
#
#
# HPOINTS
# - Definition: A Hydraulic point (or H-point) is a representation of an important hydraulic point with regard
# to the sewers.
# - This concerns points of the type: inlet, transfer point, overflow, pump, reservoir, outlet and
# purification station. An H-point is identified by the identifier assigned by the VMM, the data manager.
#
# KOPPNT
# - Koppnt is a coupling point. A coupling point is a point where two or more strands are connected. A coupling point is identified by the identifier assigned by the VMM, the data manager.

# %%
# path = data_src / "flanders_sewernetwork/Streng.shp"
sewer_edges = load_data(config.data_src / "flanders_sewernetwork/Streng.shp", PROJ_CRS)

# path = data_src / "flanders_sewernetwork/Hydpnt.shp"
data_hpoint_gml = load_data(config.data_src / "flanders_sewernetwork/Hydpnt.shp", PROJ_CRS)

# path = data_src / "flanders_sewernetwork/Koppnt.shp"
koppnt_data = load_data(config.data_src / "flanders_sewernetwork/Koppnt.shp", PROJ_CRS)
# Out:
# (327212, 28)
# Project crs: EPSG:31370
# (36190, 22)
# Project crs: EPSG:31370
# (336225, 5)
# Project crs: EPSG:31370

# %% [markdown]
# Merge Koppnt and hydpnt datasets to get the properties of the hydraulic points to the nodes.

# %%
# merged_sewer_nodes = pd.merge(
#     koppnt_data, data_hpoint_gml, left_on="NRKPNT", right_on="CODEKOPPNT", how="left"
# )
joined_sewer_nodes = gpd.overlay(koppnt_data, data_hpoint_gml, how='union', keep_geom_type=False, make_valid=False)

# %%
drop_cols = ['OIDN_1', 'UIDN_1', 'OIDN_2', 'UIDN_2']
all_sewer_nodes = joined_sewer_nodes.drop(drop_cols, axis=1)

#Copy values from similar columns in the joined datasets
all_sewer_nodes.loc[all_sewer_nodes['NRKPNT'].isnull(), 'NRKPNT'] = all_sewer_nodes['CODEKOPPNT']
all_sewer_nodes.loc[all_sewer_nodes['RWZI_1'].isnull(), 'RWZI_1'] = all_sewer_nodes['RWZI_2']

# %%
all_sewer_nodes = all_sewer_nodes.convert_dtypes()

# %%
nodes_drop_cols = ['RWZI_1', 'RWZI_2', 'TYPE', 'UITLWAT', 'GUPPROJ']
all_sewer_nodes_final = all_sewer_nodes.drop(columns=(nodes_drop_cols))

# %%
all_sewer_nodes_final.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 366664 entries, 0 to 366663
# Data columns (total 17 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   NRKPNT      366664 non-null  string
#  1   NRHPNT      36098 non-null   Int64
#  2   LBLTYPE     36098 non-null   string
#  3   STATUS      36098 non-null   string
#  4   CODEUITL    22191 non-null   string
#  5   LBLUITLWAT  36098 non-null   string
#  6   VHAS        36098 non-null   Int64
#  7   NAAMWTL     18540 non-null   string
#  8   CODEKOPPNT  36098 non-null   string
#  9   VRSTLLNG    36098 non-null   Int64
#  10  LBLVRSTLNG  36098 non-null   string
#  11  STARTDATUM  36098 non-null   string
#  12  STOPDATUM   36098 non-null   string
#  13  RENDATUM    36098 non-null   string
#  14  NISCODE     36098 non-null   string
#  15  GEMEENTE    36098 non-null   string
#  16  geometry    366664 non-null  geometry
# dtypes: Int64(3), geometry(1), string(13)
# memory usage: 48.6 MB

# %% [markdown]
# Save sewer network nodes and edges to file.

# %%
# all_sewer_nodes_final.to_file(config.data_dest / "VL_sewernodesPROCESSED.shp")

# %% [markdown]
# ### Create connection lines between the sewer points and hydraulic points

# %%
def make_intersection_lines(df, from_point, to_point):
    lines = []
    for index, row in df.iterrows():
        p_1 = Point(row[from_point])
        p_2 = Point(row[to_point])
        intersect = LineString([p_1, p_2])
        # linestring = loads(intersect)
        lines.append(intersect)
    return lines

# %%
merged_sewer_nodes = pd.merge(
    koppnt_data, data_hpoint_gml, left_on="NRKPNT", right_on="CODEKOPPNT", how="left"
)

connection_df = merged_sewer_nodes[merged_sewer_nodes['geometry_y'].notna()]

connection_df['connection_lines'] = make_intersection_lines(connection_df, 'geometry_x', 'geometry_y')


connection_lines_df = gpd.GeoDataFrame(
                (connection_df[['CODEKOPPNT', 'LBLTYPE', 'NAAMWTL', 'LBLUITLWAT', 'LBLVRSTLNG', 'RWZI_y', 'connection_lines']].rename(
                        columns={"connection_lines": "geometry"}
                    )
                ),
                geometry="geometry",
                crs=PROJ_CRS,
            ).reset_index(drop=True)

connection_lines_df["New_ID"] = range(1, len(connection_lines_df) + 1)
connection_lines_df["newID"] = 'CONN_' + connection_lines_df["New_ID"].astype(str)

connection_lines_df = connection_lines_df.drop('New_ID', axis=1)

connection_lines_df['fictitious'] = 'true'

# %%
# BEGINKPNT	EINDKPNT
connection_lines_df = connection_lines_df.rename(columns={'CODEKOPPNT': 'BEGINKPNT', 'newID':'NRSTRENG', 'RWZI_y':'RWZI'})
connection_lines_df['EINDKPNT'] = connection_lines_df.loc[:, 'BEGINKPNT']

# %%
connection_lines_df.columns
# Out:
# Index(['BEGINKPNT', 'LBLTYPE', 'NAAMWTL', 'LBLUITLWAT', 'LBLVRSTLNG', 'RWZI',
#        'geometry', 'NRSTRENG', 'fictitious', 'EINDKPNT'],
#       dtype='object')

# %%
sewer_edges_merged = pd.concat([sewer_edges, connection_lines_df], join='outer')
assert connection_lines_df.shape[0] + sewer_edges.shape[0] == sewer_edges_merged.shape[0]

# %%
drop_cols = ['OIDN', 'UIDN', 'LEIDING', 'VRSTLLNG', 'RWZI', 'LENGTE', 'LBLTYPE', 'NAAMWTL', 'LBLUITLWAT', 'GUPPROJ', 'STRAATNMID', 'STRAATNM', 'INW', 'FUNCTIE', 'WATER']
sewer_edges_final = sewer_edges_merged.drop(columns=(drop_cols))

# %%
sewer_edges_final.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sewer_edges_final.sample(5)
#
# NameError: name 'sewer_edges_final' is not defined

# %%
{'s_line_id':'NRSTRENG',
'status':'STATUS',
'start_ID':'BEGINKPNT',
'end_ID':'EINDKPNT',
's_node_id':'snode_id',
'start_date':'STARTDATUM',
'end_date':'STOPDATUM',
'ren_date':'RENDATUM',
'water_type':'LBLWATER',
'pipe_type':'LBLLEIDING',
'function':'LBLFUNCTIE'}

# %%
sewer_edges_final.columns
# Out:
# Index(['NRSTRENG', 'STATUS', 'BEGINKPNT', 'EINDKPNT', 'LBLFUNCTIE',
#        'LBLLEIDING', 'LBLWATER', 'BRON', 'LBLBRON', 'STARTDATUM', 'STOPDATUM',
#        'RENDATUM', 'NRHPNT', 'LBLVRSTLNG', 'PERCUITL', 'geometry',
#        'fictitious'],
#       dtype='object')

# %%
# connection_lines_df.to_file('data/test_data/sewer_connection_lines.shp')
# sewer_edges_final.to_file(config.data_dest / "VL_seweredgesPROCESSED.shp")

# %% [markdown]
# ### 2. Expose external nodes
#
# Expose external nodes in the sewer dataset. External nodes are end points of a strand that are not beginpoints of another strand. Here, using the attributes 'BEGINKPNT' and 'EINDKPNT' which are the node codes, we can find the external nodes.

# %%
def find_external_nodes(df, begin_col, end_col):

    """This function extracts the endpoints of a sewer segment
    that are not beginpoints of another sewer segment"""

    beginpoints = df[begin_col].to_list()
    endpoints = df[end_col].to_list()
    beginpoints_set = set(beginpoints)
    endpoints_set = set(endpoints)
    external_nodes = list(endpoints_set - beginpoints_set)
    return external_nodes

# %%
external_nodes = find_external_nodes(sewer_edges, "BEGINKPNT", "EINDKPNT")

ext_nodes_df = (
    data_hpoint_gml.query("CODEKOPPNT in @external_nodes")
    .query("VHAS != 0")
    .drop_duplicates(subset="CODEKOPPNT")
    .drop(columns=["geometry"])
    .merge(koppnt_data[["NRKPNT", "geometry"]], left_on="CODEKOPPNT", right_on="NRKPNT")
    .drop(columns=["NRKPNT"])
    .drop_duplicates(subset="geometry")
)

# %%
assert ext_nodes_df.geometry.nunique() == ext_nodes_df.CODEKOPPNT.nunique()

# %%
ext_nodes_df.shape
# Out:
# (14440, 22)

# %% [markdown]
# ## FIND CONNECTION NODES

# %% [markdown]
# Use a custom function to identify a connection point by projecting to the nearest point on a river from an external node.
#
# The expected output is a df with sewer nodes projected onto water segments.

# %%
def get_nearest_point(df, line_col, point_col):
    """
    For each point in points_df, find the nearest point in lines_df.
    """
    geoms = []
    for idx, row in df.iterrows():
        destinations = MultiPoint(np.array(row[line_col].coords))
        # destinations = MultiPoint(row[line_col].coords)  # geometry_y
        nearest_geoms = nearest_points(row[point_col], destinations)  # geometry_x
        try:
            for coord in destinations.geoms:
                if coord == nearest_geoms[1]:
                    geoms.append(coord)
        except ValueError:
            print("No nearest point found for {}".format(row.CODEKOPPNT))
    return geoms

# %%
assert len(water_final) == water_final.VHAS.nunique()

# %%
water_final_cols = ["VHAS", "geometry"]
ext_nodes_cols = ["NRHPNT", "CODEKOPPNT", "VHAS", "geometry"]
sewer_water_df = (
    ext_nodes_df[ext_nodes_cols]
    .merge(water_final[water_final_cols], on="VHAS", how="left")
    .drop_duplicates(subset="geometry_x", keep="first")
    .query("geometry_y.notnull()")
    .assign(new_points=lambda x: get_nearest_point(x, "geometry_y", "geometry_x"))
)
print(sewer_water_df.shape)

sewer_water_df = gpd.GeoDataFrame(
    sewer_water_df, geometry="new_points", crs=PROJ_CRS
).drop_duplicates(subset="new_points")

conn_node_cols = ["NRHPNT", "CODEKOPPNT", "VHAS", "new_points"]
water_cols = ["VHAS", "CODEKOPPNT", "geometry_y"]
connection_nodes_df = (
    sewer_water_df[conn_node_cols]
    .rename(columns={"new_points": "geometry"})
    .reset_index(drop=True)
)

connection_nodes_gdf = gpd.GeoDataFrame(
    connection_nodes_df, geometry="geometry", crs=PROJ_CRS
)
print("Connection_nodes_df: ", connection_nodes_gdf.shape)

water_df = (
    sewer_water_df[water_cols]
    .rename(columns={"geometry_y": "geometry"})
    .reset_index(drop=True)
)
water_gdf = gpd.GeoDataFrame(water_df, geometry="geometry", crs=PROJ_CRS)
print("Water_df: ", water_gdf.shape)
# Out:
# (13904, 6)
# Connection_nodes_df:  (11699, 4)
# Water_df:  (11699, 3)

# %%
print(sewer_water_df.shape)
sewer_water_df.head(2)
# Out:
# (11699, 6)
#       NRHPNT     CODEKOPPNT     VHAS                    geometry_x  \
# 0  6025960.0  24195613725_1  6033745  POINT (49632.228 215175.512)
# 1  6028829.0      7165620_1  6002399  POINT (63142.598 172228.907)
#
#                                           geometry_y  \
# 0  LINESTRING (49842.161 215096.866, 49720.629 21...
# 1  LINESTRING (64485.050 172900.574, 64483.883 17...
#
#                      new_points
# 0  POINT (49720.629 215107.628)
# 1  POINT (63142.133 172229.301)

# %%
connection_nodes_gdf.head(2)
# Out:
#       NRHPNT     CODEKOPPNT     VHAS                      geometry
# 0  6025960.0  24195613725_1  6033745  POINT (49720.629 215107.628)
# 1  6028829.0      7165620_1  6002399  POINT (63142.133 172229.301)

# %%
# connection_nodes_gdf.to_file('../data/test_data2/connection_nodes.shp')
# nodes_gdf_upload = nodes_gdf.drop(columns=['coords'])
# connection_nodes_gdf.to_file(r"data_transform\\vl_connection_nodes_PROCESSED.shp")

# %%
#![4.connection_nodes.PNG](attachment:4.connection_nodes.PNG)

# %% [markdown]
# ## Join the sewer network to the water network
#
# This is done by transforming the linestring and point geometries into coordinates, and using these coordinates to identify split points on a water segment.

# %%
def get_point_coords(gdf):

    """Returns coordinates as tuples of coordinates"""

    return gdf.geometry.apply(lambda geom: (geom.x, geom.y))


def get_line_coords(line):

    """Returns a list of tuples of coordinates"""

    coords_list = []
    multi_points = np.array(line.coords)
    for i in multi_points:
        geom = Point(i)
        long, lat = geom.x, geom.y
        coords_list.append((long, lat))

    return coords_list

# %%
# print(connection_nodes_gdf.shape)
# print(connection_nodes_gdf.geometry.nunique())
nodes_gdf = connection_nodes_gdf.copy()
nodes_gdf["coords"] = get_point_coords(nodes_gdf)

water_gdf["coords"] = water_gdf.apply(lambda row: get_line_coords(row.geometry), axis=1)
print(water_gdf.shape)
# Out:
# (11699, 4)

# %%
nodes_gdf.shape
# Out:
# (11699, 5)

# %%
#connection_nodes_gdf.to_file()

# %% [markdown]
# ## Split function
#
# The split function splits the water segements where the sewer empties into the river, and creates a split. One segment can have several splits. All the split segments, using the unique identifier of the original segment are added onto a split segment dataframe.

# %%
def get_line_segments(l, points_list):

    idx_list = [
        i for i, item in enumerate(l) if item in points_list
    ]  # compares the two lists and returns the indexes of occurence

    p = [l[i] for i in idx_list]  # get correct order of points list on the line

    super_list = []

    start_idx = 0

    # print("Index list: ", idx_list)
    if len(idx_list) == 1 and (
        p[0] == l[0] or p[0] == l[-1]
    ):  #      (i == 0 or i == len(l)-1) and len(idx_list) == 1:
        print("One split point, at first or last index")
        line_segment = LineString(l)
        super_list.append(line_segment)

    elif len(idx_list) == 2 and (p[0] == l[0] or p[1] == l[-1]):
        print("Two split points, at first and last index")
        line_segment = LineString(l)
        super_list.append(line_segment)

    else:
        # import pdb; pdb.set_trace()
        for i in idx_list:
            # In the case of the first coordinates of a line being a split point but there are other split points
            if i == 0 and len(idx_list) > 1:
                index_list = len(idx_list)
                print(f"First index is a split point, with {index_list} split points")
                continue
            elif i != 0 and len(idx_list) == 1:
                stop_idx = i + 1
                print(f"One split point at index {i}")
                print('stop_idx:', stop_idx)
                print('length of list:', len(l))
                if len(l) - stop_idx == 1:
                    last_segment = l #[stop_idx-1: len(l)+1]
                    last_segment_geom = LineString(last_segment)
                    super_list.append(last_segment_geom)
                else:
                    print(f"One split point at index {i}")
                    # stop_idx = i + 1  # grab list elements until index i
                    print(f"stop index is {stop_idx}")
                    line_list = l[start_idx:stop_idx]
                    line_segment = LineString(line_list)
                    super_list.append(line_segment)
                    print('index_list:' ,len(idx_list))
                    print('stop_idx:', stop_idx)
                    print('length of list:', len(l))
                    if len(l) > stop_idx:
                        last_segment = l[i: len(l)+1]
                        last_segment_geom = LineString(last_segment)
                        super_list.append(last_segment_geom)

            else:
                print("Many split points")
                stop_idx = i + 1  # grab list elements until index i
                print(f"stop index is {stop_idx}")

                line_list = l[start_idx:stop_idx]
                line_segment = LineString(line_list)
                super_list.append(line_segment)
                start_idx = (
                    i  # reset the start index to the number of the prevous stop index
                )

                # super list still has one more segment to add
                print('Super_list:', len(super_list))
                print('index_list:' ,len(idx_list))
                print('stop_idx:', stop_idx)
                print('length of list:', len(l))
                if len(idx_list) - len(super_list)  == 1:
                    print('super list still has one more segment to add')
                    # last_segment = l[stop_idx - 1 : len(l)]
                    last_segment = l[i: len(l)+1]
                    # print('stop_idx:', stop_idx)
                    # print('length of list:', len(l))
                    if stop_idx == len(l):
                        print("Split point at end of list") # stop index goes beyond the line list
                        break
                    # n = len(l) - len(super_list)
                    # last_segment = l[stop_idx-1:len(l)] # Grab the last segments of the list from the prevous stop_idx-1, to the end of the lin len(l)
                    elif len(l) - stop_idx == 1:
                        del super_list[-1]
                        last_segment = l[i: len(l)+1]
                        last_segment_geom = LineString(last_segment)
                        super_list.append(last_segment_geom)

                    else:
                        last_segment_geom = LineString(last_segment)
                        super_list.append(last_segment_geom)
                        print("Last segment added")
                # elif len(super_list) < len(idx_list):
                #     last_segment = l[stop_idx - 1 : len(l)]

    return super_list


# pass a dataframe to the function
def split_lines(water_gdf, nodes_gdf, unique_id):

    water_no_duplicates = water_gdf.drop_duplicates(subset=unique_id)

    groups = nodes_gdf.groupby(unique_id)

    codes_list = nodes_gdf[unique_id].to_list()
    unique_code_list = list(set(codes_list))

    all_segments = []
    ids = []
    # counter = 0

    for num, i in enumerate(unique_code_list):
        points_list = groups.get_group(i).coords.to_list()
        # print("Points list: ", points_list)

        # print(points_list)
        line = water_no_duplicates[water_no_duplicates[unique_id] == i]["coords"][:1]
        # indx = water_no_duplicates[water_no_duplicates[unique_id] == i].index [0]

        points_list = groups.get_group(i).coords.to_list()

        line_segments = get_line_segments(*line, points_list)
        num_segments = len(line_segments)

        all_segments.extend(line_segments)
        # ids.append(indx)
        num_unique_ids = [i] * num_segments
        # get group for each unique code
        # group_ids = groups.get_group(i)[unique_id].to_list()

        # assert len(flat_list) == len(water_no_duplicates)
        ids.extend(num_unique_ids)

        print(f"Line: {i}")
        print(f'len({line_segments}) line_segments added')
        # print(line_segments)
        # all_segments = all_segments.extend(line_segment)

    ## Create dataframe with all segments
    print(len(all_segments))
    print(len(ids))
    # ids_list = list(range(len(ids)))
    gdf_segments = gpd.GeoDataFrame(
        list(range(len(all_segments))), geometry=all_segments, crs=PROJ_CRS
    )
    # gdf_segments = gpd.GeoDataFrame(gdf_segments, geometry='geometry', crs=PROJ_CRS)
    gdf_segments.columns = ["index", "geometry"]
    gdf_segments[unique_id] = ids
    gdf_segments = gdf_segments.set_index("index")
    return gdf_segments

# %% [markdown]
# **Perform test**

# %%
# test_water = water_gdf[water_gdf['VHAS']==7021447]
# test_nodes = nodes_gdf[nodes_gdf['VHAS']==7021447]
test_water = water_gdf[water_gdf['VHAS']==6034005]
test_nodes = nodes_gdf[nodes_gdf['VHAS']==6034005]

# %%
test_water
# Out:
#          VHAS CODEKOPPNT                                           geometry  \
# 3476  6034005  7150580_1  LINESTRING (28837.991 200433.859, 28776.999 20...
# 6621  6034005  7180940_1  LINESTRING (28837.991 200433.859, 28776.999 20...
# 6622  6034005  7180965_1  LINESTRING (28837.991 200433.859, 28776.999 20...
#
#                                                  coords
# 3476  [(28837.990739999746, 200433.85949997976), (28...
# 6621  [(28837.990739999746, 200433.85949997976), (28...
# 6622  [(28837.990739999746, 200433.85949997976), (28...

# %%
test_nodes
# Out:
#          NRHPNT CODEKOPPNT     VHAS                      geometry  \
# 3476  6025773.0  7150580_1  6034005  POINT (28837.991 200433.859)
# 6621  6032039.0  7180940_1  6034005  POINT (28387.987 200156.375)
# 6622  6032047.0  7180965_1  6034005  POINT (28421.054 200194.617)
#
#                                         coords
# 3476  (28837.990739999746, 200433.85949997976)
# 6621   (28387.986739999047, 200156.3754999796)
# 6622  (28421.053740000716, 200194.61719997786)

# %%
test_split = split_lines(test_water, test_nodes, "VHAS")
# Out:
# First index is a split point, with 3 split points
# Many split points
# stop index is 31
# Super_list: 1
# index_list: 3
# stop_idx: 31
# length of list: 39
# Many split points
# stop index is 37
# Super_list: 2
# index_list: 3
# stop_idx: 37
# length of list: 39
# super list still has one more segment to add
# Last segment added
# Line: 6034005
# len([<LINESTRING (28837.991 200433.859, 28776.999 200424.313, 28759.188 200412.07...>, <LINESTRING (28421.054 200194.617, 28420.47 200191.701, 28422.998 200182.369...>, <LINESTRING (28387.987 200156.375, 28402.803 200102.672, 28423.682 200017.959)>]) line_segments added
# 3
# 3

# %% [markdown]
# **Apply on whole dataframe**

# %%
import time

initialTime = time.time()
splitlines_df = split_lines(water_gdf, nodes_gdf, "VHAS")
finishTime = time.time()
# print(ids)
print(splitlines_df.shape)
print(splitlines_df.crs)
print(f"Time taken: {finishTime - initialTime}")
print("********************************************************")
# Out:
# One split point at index 3
# stop_idx: 4
# length of list: 276
# One split point at index 3
# stop index is 4
# index_list: 1
# stop_idx: 4
# length of list: 276
# Line: 32768
# len([<LINESTRING (138979.165 172375.119, 138977.345 172382.688, 138977.33 172382....>, <LINESTRING (138977.309 172382.827, 138977.282 172382.922, 138977.26 172382....>]) line_segments added
# One split point at index 53
# stop_idx: 54
# length of list: 117
# One split point at index 53
# stop index is 54
# index_list: 1
# stop_idx: 54
# length of list: 117
# Line: 32776
# len([<LINESTRING (139426.094 170006.797, 139438.876 170030.61, 139457.922 170057....>, <LINESTRING (139710.263 170419.798, 139711.638 170421.174, 139714.152 170423...>]) line_segments added
# One split point at index 130
# stop_idx: 131
# length of list: 144
# One split point at index 130
# stop index is 131
# index_list: 1
# stop_idx: 131
# length of list: 144
# Line: 32784
# len([<LINESTRING (138841.797 171003.798, 138847.552 171017.45, 138849.179 171024....>, <LINESTRING (139310.071 171426.947, 139321.184 171439.775, 139321.898 171440...>]) line_segments added
# One split point, at first or last index
# Line: 32813
# len([<LINESTRING (137391.169 169511.875, 137381.318 169553.268, 137362.643 169647...>]) line_segments added
# Many split points
# stop index is 13
# Super_list: 1
# index_list: 2
# stop_idx: 13
# length of list: 52
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 48
# Super_list: 3
# index_list: 2
# stop_idx: 48
# length of list: 52
# Line: 32835
# len([<LINESTRING (141711.678 172378.458, 141709.567 172388.284, 141706.379 172391...>, <LINESTRING (141743.447 172443.397, 141755.79 172458.479, 141760.195 172464....>, <LINESTRING (141743.447 172443.397, 141755.79 172458.479, 141760.195 172464....>]) line_segments added
# One split point at index 4
# stop_idx: 5
# length of list: 54
# One split point at index 4
# stop index is 5
# index_list: 1
# stop_idx: 5
# length of list: 54
# Line: 6029381
# len([<LINESTRING (156511.714 183973.432, 156511.763 183977.403, 156508.195 184035...>, <LINESTRING (156474.858 184178.696, 156362.275 184636.554, 156344.782 184714...>]) line_segments added
# One split point at index 3
# stop_idx: 4
# length of list: 14
# One split point at index 3
# stop index is 4
# index_list: 1
# stop_idx: 4
# length of list: 14
# Line: 32839
# len([<LINESTRING (141708.597 172304.868, 141715.873 172315.054, 141718.519 172319...>, <LINESTRING (141718.624 172322.145, 141714.337 172328.135, 141713.333 172332...>]) line_segments added
# Two split points, at first and last index
# Line: 32841
# len([<LINESTRING (140963.954 170643.5, 141001.657 170740.484, 141008.125 170774.7...>]) line_segments added
# One split point, at first or last index
# Line: 32847
# len([<LINESTRING (141409.637 171001.952, 141411.453 170999.875, 141420.969 170987...>]) line_segments added
# One split point, at first or last index
# Line: 32852
# len([<LINESTRING (141585.547 170854.234, 141582.907 170864.281, 141581.844 170875...>]) line_segments added
# One split point at index 7
# stop_idx: 8
# length of list: 22
# One split point at index 7
# stop index is 8
# index_list: 1
# stop_idx: 8
# length of list: 22
# Line: 32853
# len([<LINESTRING (141542.797 171005.407, 141554.453 171040.36, 141558.688 171058....>, <LINESTRING (141591.766 171163.125, 141599.438 171180.594, 141605.516 171198...>]) line_segments added
# One split point at index 10
# stop_idx: 11
# length of list: 24
# One split point at index 10
# stop index is 11
# index_list: 1
# stop_idx: 11
# length of list: 24
# Line: 32854
# len([<LINESTRING (141589.375 171263.672, 141615.48 171310.459, 141632.25 171339.6...>, <LINESTRING (141682.049 171429.521, 141697.501 171443.65, 141722.107 171470....>]) line_segments added
# One split point at index 60
# stop_idx: 61
# length of list: 62
# Line: 6029440
# len([<LINESTRING (115726.399 186294.797, 115735.96 186301.554, 115742.35 186304.6...>]) line_segments added
# One split point at index 17
# stop_idx: 18
# length of list: 37
# One split point at index 17
# stop index is 18
# index_list: 1
# stop_idx: 18
# length of list: 37
# Line: 6029442
# len([<LINESTRING (113574.998 183882.265, 113579.233 183887.075, 113583.921 183892...>, <LINESTRING (113640.67 183978.881, 113646.77 183985.485, 113649.113 183987.4...>]) line_segments added
# One split point, at first or last index
# Line: 6029445
# len([<LINESTRING (112274.207 189830.129, 112277.623 189830.414, 112289.919 189830...>]) line_segments added
# One split point at index 8
# stop_idx: 9
# length of list: 75
# One split point at index 8
# stop index is 9
# index_list: 1
# stop_idx: 9
# length of list: 75
# Line: 6029449
# len([<LINESTRING (115692.931 189595.308, 115697.443 189598.341, 115720.488 189609...>, <LINESTRING (115780.681 189627.234, 115792.375 189633.081, 115801.909 189638...>]) line_segments added
# One split point, at first or last index
# Line: 6029450
# len([<LINESTRING (114866.683 184926.298, 114874.174 184929.052, 114882.694 184932...>]) line_segments added
# One split point at index 14
# stop_idx: 15
# length of list: 123
# One split point at index 14
# stop index is 15
# index_list: 1
# stop_idx: 15
# length of list: 123
# Line: 6029451
# len([<LINESTRING (113974.551 189006.001, 113983.319 189002.889, 113991.707 189000...>, <LINESTRING (114021.901 188860.601, 114023.656 188843.046, 114025.216 188840...>]) line_segments added
# One split point at index 13
# stop_idx: 14
# length of list: 198
# One split point at index 13
# stop index is 14
# index_list: 1
# stop_idx: 14
# length of list: 198
# Line: 6029452
# len([<LINESTRING (116064.485 188927.764, 116051.15 189001.424, 116048.186 189024....>, <LINESTRING (116236.57 189125.885, 116246.942 189128.848, 116257.737 189133....>]) line_segments added
# Many split points
# stop index is 10
# Super_list: 1
# index_list: 2
# stop_idx: 10
# length of list: 23
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 21
# Super_list: 3
# index_list: 2
# stop_idx: 21
# length of list: 23
# Line: 6029461
# len([<LINESTRING (116467.865 190269.122, 116474.538 190275.95, 116485.915 190286....>, <LINESTRING (116605.984 190330.955, 116614.582 190329.923, 116626.965 190324...>, <LINESTRING (116605.984 190330.955, 116614.582 190329.923, 116626.965 190324...>]) line_segments added
# One split point at index 4
# stop_idx: 5
# length of list: 16
# One split point at index 4
# stop index is 5
# index_list: 1
# stop_idx: 5
# length of list: 16
# Line: 6029472
# len([<LINESTRING (111884.04 187538.188, 111936.297 187485.704, 111951.774 187471....>, <LINESTRING (112045.899 187403.906, 112100.469 187373.609, 112140.688 187349...>]) line_segments added
# One split point, at first or last index
# Line: 1999014
# len([<LINESTRING (103241.691 197836.715, 103231.007 197851.54, 103134.416 197985....>]) line_segments added
# One split point at index 3
# stop_idx: 4
# length of list: 32
# One split point at index 3
# stop index is 4
# index_list: 1
# stop_idx: 4
# length of list: 32
# Line: 1999016
# len([<LINESTRING (92864.387 202176.959, 92895.99 202182.5, 92898.752 202176.262, ...>, <LINESTRING (92905.553 202173.462, 92958.148 202196.507, 92958.215 202197.02...>]) line_segments added
# One split point at index 17
# stop_idx: 18
# length of list: 19
# Line: 6029485
# len([<LINESTRING (113853.857 187514.003, 113853.946 187514.518, 113856.354 187516...>]) line_segments added
# One split point, at first or last index
# Line: 6029486
# len([<LINESTRING (113593.668 185855.938, 113603.961 185870.219, 113608.196 185883...>]) line_segments added
# Two split points, at first and last index
# Line: 6029489
# len([<LINESTRING (113986.346 190673.711, 114018.5 190665.406, 114067.328 190651.3...>]) line_segments added
# One split point at index 3
# stop_idx: 4
# length of list: 6
# One split point at index 3
# stop index is 4
# index_list: 1
# stop_idx: 4
# length of list: 6
# Line: 6029498
# len([<LINESTRING (112908.992 188482.218, 112919.071 188485.594, 112923.024 188459...>, <LINESTRING (112925.756 188442.515, 112963.766 188453.297, 112966.877 188453...>]) line_segments added
# First index is a split point, with 3 split points
# Many split points
# stop index is 3
# Super_list: 1
# index_list: 3
# stop_idx: 3
# length of list: 33
# Many split points
# stop index is 28
# Super_list: 2
# index_list: 3
# stop_idx: 28
# length of list: 33
# super list still has one more segment to add
# Last segment added
# Line: 6029500
# len([<LINESTRING (113200.777 189473.563, 113206.148 189465.399, 113214.561 189459...>, <LINESTRING (113214.561 189459.767, 113227.421 189453.969, 113245.836 189447...>, <LINESTRING (113461.86 189187.141, 113496.789 189162.266, 113523.712 189144....>]) line_segments added
# Two split points, at first and last index
# Line: 6029503
# len([<LINESTRING (116097.567 184724.532, 116093.258 184722.146, 116086.397 184719...>]) line_segments added
# One split point, at first or last index
# Line: 32964
# len([<LINESTRING (135739.072 174134.193, 135652.328 174188.969, 135651.844 174189...>]) line_segments added
# One split point at index 4
# stop_idx: 5
# length of list: 8
# One split point at index 4
# stop index is 5
# index_list: 1
# stop_idx: 5
# length of list: 8
# Line: 6029514
# len([<LINESTRING (112529.704 190499.328, 112577.852 190482.141, 112619.665 190468...>, <LINESTRING (112714.376 190433.188, 112689.508 190360.703, 112803.805 190321...>]) line_segments added
# Many split points
# stop index is 7
# Super_list: 1
# index_list: 4
# stop_idx: 7
# length of list: 68
# Many split points
# stop index is 40
# Super_list: 2
# index_list: 4
# stop_idx: 40
# length of list: 68
# Many split points
# stop index is 51
# Super_list: 3
# index_list: 4
# stop_idx: 51
# length of list: 68
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 59
# Super_list: 5
# index_list: 4
# stop_idx: 59
# length of list: 68
# Line: 32976
# len([<LINESTRING (135940.924 171262.501, 135940.719 171262.781, 135937.826 171267...>, <LINESTRING (135888.141 171298.375, 135880.254 171300.976, 135871.893 171306...>, <LINESTRING (135708.38 171326.482, 135706.687 171325.847, 135698.855 171322....>, <LINESTRING (135650.797 171283.094, 135615.134 171288.845, 135587.73 171294....>, <LINESTRING (135650.797 171283.094, 135615.134 171288.845, 135587.73 171294....>]) line_segments added
# Many split points
# stop index is 3
# Super_list: 1
# index_list: 2
# stop_idx: 3
# length of list: 116
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 97
# Super_list: 3
# index_list: 2
# stop_idx: 97
# length of list: 116
# Line: 32978
# len([<LINESTRING (135110.44 170591.246, 135129.742 170626.811, 135130.594 170628....>, <LINESTRING (135130.594 170628.985, 135135.827 170633.637, 135141.119 170638...>, <LINESTRING (135130.594 170628.985, 135135.827 170633.637, 135141.119 170638...>]) line_segments added
# One split point at index 28
# stop_idx: 29
# length of list: 49
# One split point at index 28
# stop index is 29
# index_list: 1
# stop_idx: 29
# length of list: 49
# Line: 6029532
# len([<LINESTRING (116718.086 184555.325, 116710.677 184564.03, 116704.01 184571.0...>, <LINESTRING (116560.751 184737.701, 116560.204 184747, 116559.917 184756.555...>]) line_segments added
# Two split points, at first and last index
# Line: 6029533
# len([<LINESTRING (117014.813 184582.547, 116883.177 184464.769, 116880.525 184473...>]) line_segments added
# Many split points
# stop index is 21
# Super_list: 1
# index_list: 2
# stop_idx: 21
# length of list: 211
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 144
# Super_list: 3
# index_list: 2
# stop_idx: 144
# length of list: 211
# Line: 6029535
# len([<LINESTRING (113818.484 184862.696, 113823.145 184859.584, 113831.347 184852...>, <LINESTRING (114024.349 184951.442, 114026.635 184951.442, 114035.779 184936...>, <LINESTRING (114024.349 184951.442, 114026.635 184951.442, 114035.779 184936...>]) line_segments added
# Many split points
# stop index is 25
# Super_list: 1
# index_list: 3
# stop_idx: 25
# length of list: 125
# Many split points
# stop index is 30
# Super_list: 2
# index_list: 3
# stop_idx: 30
# length of list: 125
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 84
# Super_list: 4
# index_list: 3
# stop_idx: 84
# length of list: 125
# Line: 6029544
# len([<LINESTRING (114893.237 183077.954, 114893.547 183078.512, 114893.336 183083...>, <LINESTRING (114875.133 183183.563, 114880.424 183188.22, 114883.811 183191....>, <LINESTRING (114887.198 183206.846, 114894.031 183212.532, 114899.686 183218...>, <LINESTRING (114887.198 183206.846, 114894.031 183212.532, 114899.686 183218...>]) line_segments added
# Many split points
# stop index is 85
# Super_list: 1
# index_list: 4
# stop_idx: 85
# length of list: 210
# Many split points
# stop index is 86
# Super_list: 2
# index_list: 4
# stop_idx: 86
# length of list: 210
# Many split points
# stop index is 87
# Super_list: 3
# index_list: 4
# stop_idx: 87
# length of list: 210
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 148
# Super_list: 5
# index_list: 4
# stop_idx: 148
# length of list: 210
# Line: 6029546
# len([<LINESTRING (115172.365 185063.08, 115177.033 185073.664, 115184.306 185079....>, <LINESTRING (115600.466 185450.073, 115602.133 185452.74)>, <LINESTRING (115602.133 185452.74, 115610.467 185461.241)>, <LINESTRING (115610.467 185461.241, 115617.635 185466.408, 115620.922 185469...>, <LINESTRING (115610.467 185461.241, 115617.635 185466.408, 115620.922 185469...>]) line_segments added
# Many split points
# stop index is 77
# Super_list: 1
# index_list: 3
# stop_idx: 77
# length of list: 100
# Many split points
# stop index is 90
# Super_list: 2
# index_list: 3
# stop_idx: 90
# length of list: 100
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 92
# Super_list: 4
# index_list: 3
# stop_idx: 92
# length of list: 100
# Line: 6029547
# len([<LINESTRING (116047.499 187064.309, 116047.393 187060.661, 116046.325 187057...>, <LINESTRING (115696.925 186925.518, 115691.806 186923.136, 115689.424 186921...>, <LINESTRING (115640.727 186900.515, 115622.319 186902.918, 115615.638 186902...>, <LINESTRING (115640.727 186900.515, 115622.319 186902.918, 115615.638 186902...>]) line_segments added
# One split point at index 14
# stop_idx: 15
# length of list: 64
# One split point at index 14
# stop index is 15
# index_list: 1
# stop_idx: 15
# length of list: 64
# Line: 6029555
# len([<LINESTRING (118207.532 186933.531, 118207.776 186941.681, 118208.094 186944...>, <LINESTRING (118212.807 187016.322, 118211.658 187018.094, 118210.779 187019...>]) line_segments added
# One split point at index 1
# stop_idx: 2
# length of list: 4
# One split point at index 1
# stop index is 2
# index_list: 1
# stop_idx: 2
# length of list: 4
# Line: 6029558
# len([<LINESTRING (116375.049 185784.221, 116374.782 185784.45)>, <LINESTRING (116374.782 185784.45, 116342.185 185821.915, 116341.539 185822....>]) line_segments added
# Many split points
# stop index is 99
# Super_list: 1
# index_list: 2
# stop_idx: 99
# length of list: 114
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 101
# Super_list: 3
# index_list: 2
# stop_idx: 101
# length of list: 114
# Line: 6029562
# len([<LINESTRING (116855.256 186866.67, 116824.881 186852.482, 116808.02 186843.7...>, <LINESTRING (116113.487 187079.251, 116103.3 187087.189, 116096.686 187093.2...>, <LINESTRING (116113.487 187079.251, 116103.3 187087.189, 116096.686 187093.274)>]) line_segments added
# One split point at index 10
# stop_idx: 11
# length of list: 12
# Line: 6029564
# len([<LINESTRING (113256.353 187353.908, 113262.42 187357.867, 113320.723 187392....>]) line_segments added
# One split point at index 2
# stop_idx: 3
# length of list: 12
# One split point at index 2
# stop index is 3
# index_list: 1
# stop_idx: 3
# length of list: 12
# Line: 6029566
# len([<LINESTRING (115216.459 188051.518, 115213.372 188053.356, 115211.864 188060.5)>, <LINESTRING (115211.864 188060.5, 115214.853 188091.229, 115212.313 188106.0...>]) line_segments added
# One split point at index 29
# stop_idx: 30
# length of list: 55
# One split point at index 29
# stop index is 30
# index_list: 1
# stop_idx: 30
# length of list: 55
# Line: 6029567
# len([<LINESTRING (115452.545 186837.678, 115449.487 186853.169, 115443.088 186896...>, <LINESTRING (115265.336 187170.606, 115258.034 187185.211, 115250.89 187196....>]) line_segments added
# One split point at index 10
# stop_idx: 11
# length of list: 36
# One split point at index 10
# stop index is 11
# index_list: 1
# stop_idx: 11
# length of list: 36
# Line: 6029572
# len([<LINESTRING (111582.178 189397.527, 111587.292 189403.007, 111590.441 189405...>, <LINESTRING (111631.871 189461.837, 111635.446 189467.83, 111641.811 189477....>]) line_segments added
# One split point at index 15
# stop_idx: 16
# length of list: 35
# One split point at index 15
# stop index is 16
# index_list: 1
# stop_idx: 16
# length of list: 35
# Line: 6029576
# len([<LINESTRING (112916.751 190287.469, 112960.931 190275.976, 112991.369 190268...>, <LINESTRING (113171.453 190241.389, 113174.638 190242.072, 113180.782 190240...>]) line_segments added
# One split point, at first or last index
# Line: 6029578
# len([<LINESTRING (112598.25 188507.138, 112649.969 188532.141, 112653.489 188532....>]) line_segments added
# Two split points, at first and last index
# Line: 6029579
# len([<LINESTRING (112615.297 188892.203, 112669.036 188846.698, 112685.872 188831...>]) line_segments added
# One split point, at first or last index
# Line: 6029593
# len([<LINESTRING (115345.134 189496.32, 115348.594 189501.916, 115353.357 189509....>]) line_segments added
# Two split points, at first and last index
# Line: 6029601
# len([<LINESTRING (112100.097 186950.199, 112101.332 186981.352, 112100.355 187002...>]) line_segments added
# Many split points
# stop index is 13
# Super_list: 1
# index_list: 2
# stop_idx: 13
# length of list: 25
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 14
# Super_list: 3
# index_list: 2
# stop_idx: 14
# length of list: 25
# Line: 6029602
# len([<LINESTRING (113905.239 187600.742, 113905.279 187600.876, 113907.412 187611...>, <LINESTRING (113953.546 187755.965, 113953.636 187779.278, 113951.731 187787...>, <LINESTRING (113953.546 187755.965, 113953.636 187779.278)>]) line_segments added
# One split point, at first or last index
# Line: 6029603
# len([<LINESTRING (113549.209 186873.612, 113554.79 186875.985, 113560.821 186879....>]) line_segments added
# One split point at index 40
# stop_idx: 41
# length of list: 295
# One split point at index 40
# stop index is 41
# index_list: 1
# stop_idx: 41
# length of list: 295
# Line: 6029605
# len([<LINESTRING (113677.666 186082.268, 113685.614 186101.997, 113694.346 186123...>, <LINESTRING (113793.342 186319.866, 113797.882 186329.221, 113802.55 186335....>]) line_segments added
# One split point at index 31
# stop_idx: 32
# length of list: 70
# One split point at index 31
# stop index is 32
# index_list: 1
# stop_idx: 32
# length of list: 70
# Line: 6029607
# len([<LINESTRING (113306.007 184644.994, 113306.057 184646.052, 113311.013 184644...>, <LINESTRING (113478.163 184728.121, 113484.381 184733.281, 113489.276 184737...>]) line_segments added
# One split point at index 48
# stop_idx: 49
# length of list: 207
# One split point at index 48
# stop index is 49
# index_list: 1
# stop_idx: 49
# length of list: 207
# Line: 6029609
# len([<LINESTRING (113386.874 182671.573, 113386.413 182674.206, 113387.662 182687...>, <LINESTRING (113325.132 183006.294, 113324.735 183008.014, 113324.47 183016....>]) line_segments added
# One split point at index 22
# stop_idx: 23
# length of list: 24
# Line: 33068
# len([<LINESTRING (203974.625 173934.234, 204005.876 173985.907, 204015.422 173996...>]) line_segments added
# One split point at index 15
# stop_idx: 16
# length of list: 75
# One split point at index 15
# stop index is 16
# index_list: 1
# stop_idx: 16
# length of list: 75
# Line: 6029615
# len([<LINESTRING (114835.581 183986.492, 114827.943 183975.035, 114822.262 183969...>, <LINESTRING (114756.221 183906.598, 114757.184 183904.919, 114795.157 183874...>]) line_segments added
# One split point at index 1
# stop_idx: 2
# length of list: 23
# One split point at index 1
# stop index is 2
# index_list: 1
# stop_idx: 2
# length of list: 23
# Line: 6029617
# len([<LINESTRING (116677.375 185320.457, 116677.418 185320.669)>, <LINESTRING (116677.418 185320.669, 116656.08 185337.284, 116642.719 185346....>]) line_segments added
# One split point at index 5
# stop_idx: 6
# length of list: 55
# One split point at index 5
# stop index is 6
# index_list: 1
# stop_idx: 6
# length of list: 55
# Line: 6029618
# len([<LINESTRING (116442.073 185506.057, 116442.073 185508.223, 116441.481 185512...>, <LINESTRING (116431.554 185524.433, 116425.751 185537.749, 116423.875 185542...>]) line_segments added
# One split point at index 103
# stop_idx: 104
# length of list: 130
# One split point at index 103
# stop index is 104
# index_list: 1
# stop_idx: 104
# length of list: 130
# Line: 6029621
# len([<LINESTRING (117787.883 188243.297, 117785.856 188257.658, 117769.562 188321...>, <LINESTRING (117786.13 188900.609, 117778.629 188908.11, 117763.627 188923.5...>]) line_segments added
# Many split points
# stop index is 25
# Super_list: 1
# index_list: 2
# stop_idx: 25
# length of list: 51
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 28
# Super_list: 3
# index_list: 2
# stop_idx: 28
# length of list: 51
# Line: 6029622
# len([<LINESTRING (117765.72 189131.925, 117766.485 189132.501, 117765.029 189138....>, <LINESTRING (117691.486 189267.265, 117684.047 189271.953, 117682.725 189271...>, <LINESTRING (117691.486 189267.265, 117684.047 189271.953, 117682.725 189271...>]) line_segments added
# One split point, at first or last index
# Line: 6029623
# len([<LINESTRING (116945.939 188522.882, 116949.214 188526.566, 116953.65 188531....>]) line_segments added
# One split point at index 1
# stop_idx: 2
# length of list: 5
# One split point at index 1
# stop index is 2
# index_list: 1
# stop_idx: 2
# length of list: 5
# Line: 6029625
# len([<LINESTRING (117034.556 188958.009, 117034.875 188958.203)>, <LINESTRING (117034.875 188958.203, 116967.141 189110.61, 116940.68 189185.2...>]) line_segments added
# One split point at index 1
# stop_idx: 2
# length of list: 6
# One split point at index 1
# stop index is 2
# index_list: 1
# stop_idx: 2
# length of list: 6
# Line: 33126
# len([<LINESTRING (207638.454 172583.656, 207630.454 172582.188)>, <LINESTRING (207630.454 172582.188, 207596.063 172576.625, 207564.844 172571...>]) line_segments added
# First index is a split point, with 3 split points
# Many split points
# stop index is 33
# Super_list: 1
# index_list: 3
# stop_idx: 33
# length of list: 106
# Many split points
# stop index is 106
# Super_list: 2
# index_list: 3
# stop_idx: 106
# length of list: 106
# super list still has one more segment to add
# Split point at end of list
# Line: 6029687
# len([<LINESTRING (37415.105 206687.789, 37385.394 206618.32, 37379.933 206609.57,...>, <LINESTRING (37250.578 206100.93, 37246.672 206081.555, 37242.738 206061.883...>]) line_segments added
# Two split points, at first and last index
# Line: 6029692
# len([<LINESTRING (118481.762 207428.769, 118462.688 207428.286, 118423.342 207427...>]) line_segments added
# Many split points
# stop index is 154
# Super_list: 1
# index_list: 2
# stop_idx: 154
# length of list: 253
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 175
# Super_list: 3
# index_list: 2
# stop_idx: 175
# length of list: 253
# Line: 33151
# len([<LINESTRING (205399.11 172136.735, 205394.868 172136.153, 205394.824 172136....>, <LINESTRING (205197.486 172182.993, 205197.455 172182.976, 205197.424 172182...>, <LINESTRING (205197.486 172182.993, 205197.455 172182.976, 205197.424 172182...>]) line_segments added
# Many split points
# stop index is 35
# Super_list: 1
# index_list: 2
# stop_idx: 35
# length of list: 74
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 39
# Super_list: 3
# index_list: 2
# stop_idx: 39
# length of list: 74
# Line: 6029696
# len([<LINESTRING (104066.311 195365.004, 104051.072 195428.452, 104057.263 195446...>, <LINESTRING (104376.601 196300.797, 104372.047 196308.817, 104371.588 196327...>, <LINESTRING (104376.601 196300.797, 104372.047 196308.817, 104371.588 196327...>]) line_segments added
# One split point at index 47
# stop_idx: 48
# length of list: 100
# One split point at index 47
# stop index is 48
# index_list: 1
# stop_idx: 48
# length of list: 100
# Line: 6029713
# len([<LINESTRING (103233.348 199052.127, 103276.728 199085.606, 103278.039 199086...>, <LINESTRING (104438.693 199643.734, 104439.826 199643.657, 104465.151 199641...>]) line_segments added
# Two split points, at first and last index
# Line: 6029720
# len([<LINESTRING (104948.311 197233.526, 104943.903 197281.137, 104943.903 197380...>]) line_segments added
# Many split points
# stop index is 6
# Super_list: 1
# index_list: 2
# stop_idx: 6
# length of list: 13
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 7
# Super_list: 3
# index_list: 2
# stop_idx: 7
# length of list: 13
# Line: 6029721
# len([<LINESTRING (105061.387 195833.232, 105061.541 195834.167, 105050.655 195908...>, <LINESTRING (105025.979 196306.262, 105015.819 196502.212, 104991.87 196688....>, <LINESTRING (105025.979 196306.262, 105015.819 196502.212)>]) line_segments added
# One split point at index 8
# stop_idx: 9
# length of list: 35
# One split point at index 8
# stop index is 9
# index_list: 1
# stop_idx: 9
# length of list: 35
# Line: 6029750
# len([<LINESTRING (99921.604 183087.758, 99924.065 183088.357, 99976.383 183105.5,...>, <LINESTRING (100141.025 183132.004, 100167.761 183134.097, 100211.435 183134...>]) line_segments added
# Many split points
# stop index is 22
# Super_list: 1
# index_list: 2
# stop_idx: 22
# length of list: 47
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 25
# Super_list: 3
# index_list: 2
# stop_idx: 25
# length of list: 47
# Line: 6029752
# len([<LINESTRING (104761.299 187208.752, 104767.029 187242.091, 104767.883 187272...>, <LINESTRING (104988.149 188183.774, 105034.284 188215.745, 105073.524 188237...>, <LINESTRING (104988.149 188183.774, 105034.284 188215.745, 105073.524 188237...>]) line_segments added
# One split point at index 7
# stop_idx: 8
# length of list: 14
# One split point at index 7
# stop index is 8
# index_list: 1
# stop_idx: 8
# length of list: 14
# Line: 6029753
# len([<LINESTRING (106097.288 188106.127, 106108.507 188106.438, 106130.021 188107...>, <LINESTRING (106198.762 188170.968, 106224.375 188197.434, 106247.426 188228...>]) line_segments added
# Many split points
# stop index is 30
# Super_list: 1
# index_list: 2
# stop_idx: 30
# length of list: 112
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 62
# Super_list: 3
# index_list: 2
# stop_idx: 62
# length of list: 112
# Line: 6029755
# len([<LINESTRING (99833.029 181209.361, 99831.6 181220.077, 99827.552 181256.272,...>, <LINESTRING (99872.558 181521.782, 99874.225 181527.735, 99874.618 181533.17...>, <LINESTRING (99872.558 181521.782, 99874.225 181527.735, 99874.618 181533.17...>]) line_segments added
# Two split points, at first and last index
# Line: 459
# len([<LINESTRING (153512.407 217214.172, 153493.407 217216.797, 153372.297 217248...>]) line_segments added
# One split point at index 10
# stop_idx: 11
# length of list: 16
# One split point at index 10
# stop index is 11
# index_list: 1
# stop_idx: 11
# length of list: 16
# Line: 6029775
# len([<LINESTRING (130726.297 192772.094, 130809.04 192712.438, 130829.918 192696....>, <LINESTRING (131062.327 192532.469, 131017.985 192498.576, 130990.973 192478...>]) line_segments added
# One split point at index 4
# stop_idx: 5
# length of list: 7
# One split point at index 4
# stop index is 5
# index_list: 1
# stop_idx: 5
# length of list: 7
# Line: 6029791
# len([<LINESTRING (130765.899 196026.703, 130743.861 196009.145, 130711 195980.809...>, <LINESTRING (130827.206 195874.842, 130851.679 195897.076, 130889.663 195927...>]) line_segments added
# One split point, at first or last index
# Line: 6029805
# len([<LINESTRING (110811.672 194014.653, 110866.918 194010.632, 110870.94 194008....>]) line_segments added
# Many split points
# stop index is 2
# Super_list: 1
# index_list: 3
# stop_idx: 2
# length of list: 5
# Many split points
# stop index is 3
# Super_list: 2
# index_list: 3
# stop_idx: 3
# length of list: 5
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 4
# Super_list: 4
# index_list: 3
# stop_idx: 4
# length of list: 5
# Line: 6029811
# len([<LINESTRING (110688.151 194300.859, 110700.216 194305.092)>, <LINESTRING (110700.216 194305.092, 110711.622 194278.036)>, <LINESTRING (110711.622 194278.036, 110796.406 194066.094, 110800.086 194056...>, <LINESTRING (110711.622 194278.036, 110796.406 194066.094)>]) line_segments added
# Two split points, at first and last index
# Line: 6029812
# len([<LINESTRING (110125.362 195665.286, 110123.604 195666.583, 110114.178 195673...>]) line_segments added
# One split point at index 1
# stop_idx: 2
# length of list: 4
# One split point at index 1
# stop index is 2
# index_list: 1
# stop_idx: 2
# length of list: 4
# Line: 504
# len([<LINESTRING (134646.5 216957.797, 134680.704 216875.365)>, <LINESTRING (134680.704 216875.365, 134789.183 216631.551, 134804.352 216596...>]) line_segments added
# One split point, at first or last index
# Line: 6029819
# len([<LINESTRING (80707.207 173559.067, 80725.278 173565.687, 80793.454 173588.54...>]) line_segments added
# Many split points
# stop index is 5
# Super_list: 1
# index_list: 5
# stop_idx: 5
# length of list: 40
# Many split points
# stop index is 27
# Super_list: 2
# index_list: 5
# stop_idx: 27
# length of list: 40
# Many split points
# stop index is 30
# Super_list: 3
# index_list: 5
# stop_idx: 30
# length of list: 40
# Many split points
# stop index is 39
# Super_list: 4
# index_list: 5
# stop_idx: 39
# length of list: 40
# super list still has one more segment to add
# Many split points
# stop index is 40
# Super_list: 5
# index_list: 5
# stop_idx: 40
# length of list: 40
# Line: 6029825
# len([<LINESTRING (86610.373 175556.019, 86608.941 175556.09, 86594.779 175558.218...>, <LINESTRING (86559.574 175564.474, 86541.598 175567.478, 86490.721 175575.62...>, <LINESTRING (86068.999 175531.495, 86064.501 175544.195, 86062.384 175553.98...>, <LINESTRING (85851.352 175586.528, 85774.623 175559.541)>, <LINESTRING (85851.352 175586.528, 85774.623 175559.541)>]) line_segments added
# Many split points
# stop index is 34
# Super_list: 1
# index_list: 2
# stop_idx: 34
# length of list: 95
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 81
# Super_list: 3
# index_list: 2
# stop_idx: 81
# length of list: 95
# Line: 6029826
# len([<LINESTRING (86394.367 177456.441, 86371.622 177439.707, 86344.026 177418.53...>, <LINESTRING (85928.862 177562.803, 85922.262 177559.273, 85910.905 177551.44...>, <LINESTRING (85928.862 177562.803, 85922.262 177559.273, 85910.905 177551.44...>]) line_segments added
# First index is a split point, with 3 split points
# Many split points
# stop index is 2
# Super_list: 1
# index_list: 3
# stop_idx: 2
# length of list: 174
# Many split points
# stop index is 84
# Super_list: 2
# index_list: 3
# stop_idx: 84
# length of list: 174
# super list still has one more segment to add
# Last segment added
# Line: 6029827
# len([<LINESTRING (85733.322 173947.899, 85734.629 173953.671)>, <LINESTRING (85734.629 173953.671, 85734.658 173953.755, 85735.082 173954.99...>, <LINESTRING (85771.589 174132.172, 85772.388 174134.457, 85772.475 174134.59...>]) line_segments added
# Many split points
# stop index is 5
# Super_list: 1
# index_list: 2
# stop_idx: 5
# length of list: 51
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 12
# Super_list: 3
# index_list: 2
# stop_idx: 12
# length of list: 51
# Line: 6029828
# len([<LINESTRING (84062.812 174787.178, 84059.316 174807.591, 84064.664 174818.42...>, <LINESTRING (84074.528 174828.58, 84097.25 174843.214, 84101.678 174850.339,...>, <LINESTRING (84074.528 174828.58, 84097.25 174843.214, 84101.678 174850.339,...>]) line_segments added
# Many split points
# stop index is 2
# Super_list: 1
# index_list: 8
# stop_idx: 2
# length of list: 152
# Many split points
# stop index is 24
# Super_list: 2
# index_list: 8
# stop_idx: 24
# length of list: 152
# Many split points
# stop index is 55
# Super_list: 3
# index_list: 8
# stop_idx: 55
# length of list: 152
# Many split points
# stop index is 62
# Super_list: 4
# index_list: 8
# stop_idx: 62
# length of list: 152
# Many split points
# stop index is 63
# Super_list: 5
# index_list: 8
# stop_idx: 63
# length of list: 152
# Many split points
# stop index is 65
# Super_list: 6
# index_list: 8
# stop_idx: 65
# length of list: 152
# Many split points
# stop index is 66
# Super_list: 7
# index_list: 8
# stop_idx: 66
# length of list: 152
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 96
# Super_list: 9
# index_list: 8
# stop_idx: 96
# length of list: 152
# Line: 6029829
# len([<LINESTRING (85955.024 176581.75, 85954.218 176582.61)>, <LINESTRING (85954.218 176582.61, 85951.786 176582.187, 85947.029 176580.284...>, <LINESTRING (85742.371 176446.77, 85736.675 176443.811, 85717.106 176435.353...>, <LINESTRING (85489.508 176357.866, 85472.171 176368.543, 85464.137 176375.30...>, <LINESTRING (85427.138 176422.351, 85407.898 176433.556)>, <LINESTRING (85407.898 176433.556, 85392.147 176442.964, 85380.096 176451.95)>, <LINESTRING (85380.096 176451.95, 85364.665 176461.013)>, <LINESTRING (85364.665 176461.013, 85353.456 176467.701, 85350.708 176465.90...>, <LINESTRING (85364.665 176461.013, 85353.456 176467.701, 85350.708 176465.90...>]) line_segments added
# One split point at index 6
# stop_idx: 7
# length of list: 42
# One split point at index 6
# stop index is 7
# index_list: 1
# stop_idx: 7
# length of list: 42
# Line: 6029834
# len([<LINESTRING (81635.821 173898.777, 81657.255 173895.788, 81676.964 173897.13...>, <LINESTRING (81801.563 173897.273, 81801.833 173927.511, 81799.133 173949.38...>]) line_segments added
# One split point at index 3
# stop_idx: 4
# length of list: 55
# One split point at index 3
# stop index is 4
# index_list: 1
# stop_idx: 4
# length of list: 55
# Line: 6029840
# len([<LINESTRING (82225.576 176628.907, 82231.879 176630.81, 82244.103 176646.368...>, <LINESTRING (82254.263 176682.245, 82288.077 176729.5, 82284.749 176761.033,...>]) line_segments added
# One split point at index 33
# stop_idx: 34
# length of list: 81
# One split point at index 33
# stop index is 34
# index_list: 1
# stop_idx: 34
# length of list: 81
# Line: 6029843
# len([<LINESTRING (81896.842 174747.116, 81904.229 174746.303, 81923.696 174746.83...>, <LINESTRING (82189.736 174597.058, 82195.716 174600.233, 82201.231 174600.39...>]) line_segments added
# Many split points
# stop index is 22
# Super_list: 1
# index_list: 2
# stop_idx: 22
# length of list: 37
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 23
# Super_list: 3
# index_list: 2
# stop_idx: 23
# length of list: 37
# Line: 6029844
# len([<LINESTRING (82602.286 174346.111, 82603.216 174339.603, 82604.611 174332.63...>, <LINESTRING (83058.167 174085.786, 83073.197 174075.249, 83087.763 174070.13...>, <LINESTRING (83058.167 174085.786, 83073.197 174075.249)>]) line_segments added
# Many split points
# stop index is 11
# Super_list: 1
# index_list: 5
# stop_idx: 11
# length of list: 25
# Many split points
# stop index is 12
# Super_list: 2
# index_list: 5
# stop_idx: 12
# length of list: 25
# Many split points
# stop index is 13
# Super_list: 3
# index_list: 5
# stop_idx: 13
# length of list: 25
# Many split points
# stop index is 14
# Super_list: 4
# index_list: 5
# stop_idx: 14
# length of list: 25
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 24
# Super_list: 6
# index_list: 5
# stop_idx: 24
# length of list: 25
# Line: 6029846
# len([<LINESTRING (82983.911 177415.253, 82927.974 177444.277, 82882.628 177469.85...>, <LINESTRING (82736.512 177680.697, 82736.9 177691.161)>, <LINESTRING (82736.9 177691.161, 82740.388 177699.688)>, <LINESTRING (82740.388 177699.688, 82744.652 177707.439)>, <LINESTRING (82744.652 177707.439, 82762.48 177717.904, 82793.874 177734.182...>, <LINESTRING (82744.652 177707.439, 82762.48 177717.904, 82793.874 177734.182...>]) line_segments added
# One split point at index 3
# stop_idx: 4
# length of list: 14
# One split point at index 3
# stop index is 4
# index_list: 1
# stop_idx: 4
# length of list: 14
# Line: 6029847
# len([<LINESTRING (84062.812 174787.178, 84078.069 174803.081, 84100.823 174819.22...>, <LINESTRING (84142.362 174840.122, 84196.602 174863.141, 84230.274 174884.92...>]) line_segments added
# One split point at index 12
# stop_idx: 13
# length of list: 18
# One split point at index 12
# stop index is 13
# index_list: 1
# stop_idx: 13
# length of list: 18
# Line: 536
# len([<LINESTRING (130817.298 216724.281, 130995.695 216704.906, 130996.167 216702...>, <LINESTRING (131299.659 216403.744, 131361.092 216242.508, 131364.711 216234...>]) line_segments added
# One split point at index 40
# stop_idx: 41
# length of list: 59
# One split point at index 40
# stop index is 41
# index_list: 1
# stop_idx: 41
# length of list: 59
# Line: 6029849
# len([<LINESTRING (83483.262 173935.574, 83491.471 173938.531, 83501.766 173943.01...>, <LINESTRING (83924.875 174375.311, 83932.649 174392.609, 83943.923 174420.40...>]) line_segments added
# One split point at index 2
# stop_idx: 3
# length of list: 28
# One split point at index 2
# stop index is 3
# index_list: 1
# stop_idx: 3
# length of list: 28
# Line: 6029851
# len([<LINESTRING (83811.536 176817.043, 83737.238 176831.122, 83684.822 176842.318)>, <LINESTRING (83684.822 176842.318, 83610.863 176858.263, 83561.84 176868.61,...>]) line_segments added
# One split point at index 2
# stop_idx: 3
# length of list: 9
# One split point at index 2
# stop index is 3
# index_list: 1
# stop_idx: 3
# length of list: 9
# Line: 561
# len([<LINESTRING (134822.335 216555.331, 134836.147 216523.866, 134839.322 216516...>, <LINESTRING (134839.322 216516.855, 134928.063 216317.328, 134947.14 216278....>]) line_segments added
# One split point, at first or last index
# Line: 564
# len([<LINESTRING (130465.524 216010.594, 130477.933 216006.725, 130493.102 216009...>]) line_segments added
# One split point at index 20
# stop_idx: 21
# length of list: 37
# One split point at index 20
# stop index is 21
# index_list: 1
# stop_idx: 21
# length of list: 37
# Line: 6029877
# len([<LINESTRING (80945.31 177089.449, 80967.535 177100.826, 80995.051 177118.024...>, <LINESTRING (81375.471 177393.096, 81397.942 177401.952, 81407.988 177407.10...>]) line_segments added
# Many split points
# stop index is 28
# Super_list: 1
# index_list: 2
# stop_idx: 28
# length of list: 80
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 79
# Super_list: 3
# index_list: 2
# stop_idx: 79
# length of list: 80
# Line: 6029878
# len([<LINESTRING (79260.419 176270.222, 79257.224 176278.588, 79254.723 176288.90...>, <LINESTRING (79072.937 176475.433, 79077.665 176479.9, 79086.132 176488.367,...>, <LINESTRING (79072.937 176475.433, 79077.665 176479.9, 79086.132 176488.367,...>]) line_segments added
# Many split points
# stop index is 38
# Super_list: 1
# index_list: 2
# stop_idx: 38
# length of list: 99
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 71
# Super_list: 3
# index_list: 2
# stop_idx: 71
# length of list: 99
# Line: 6029879
# len([<LINESTRING (78218.996 175337.561, 78212.868 175348.339, 78206.463 175363.1,...>, <LINESTRING (78437.459 175862.969, 78428.546 175880.793, 78416.57 175903.631...>, <LINESTRING (78437.459 175862.969, 78428.546 175880.793, 78416.57 175903.631...>]) line_segments added
# One split point at index 1
# stop_idx: 2
# length of list: 34
# One split point at index 1
# stop index is 2
# index_list: 1
# stop_idx: 2
# length of list: 34
# Line: 6029881
# len([<LINESTRING (79680.004 173742.109, 79691.769 173744.722)>, <LINESTRING (79691.769 173744.722, 79641.233 173852.937, 79619.802 173897.96...>]) line_segments added
# One split point at index 4
# stop_idx: 5
# length of list: 15
# One split point at index 4
# stop index is 5
# index_list: 1
# stop_idx: 5
# length of list: 15
# Line: 569
# len([<LINESTRING (136712.188 215845.484, 136728.771 215859.585, 136728.797 215859...>, <LINESTRING (136856.981 215942.88, 137063.405 216092.76, 137100.278 216115.2...>]) line_segments added
# One split point at index 22
# stop_idx: 23
# length of list: 33
# One split point at index 22
# stop index is 23
# index_list: 1
# stop_idx: 23
# length of list: 33
# Line: 570
# len([<LINESTRING (137239.07 216763.187, 137170.635 216726.509, 137167.751 216725....>, <LINESTRING (136636.997 216159.375, 136642.022 216140.651, 136647.615 216120...>]) line_segments added
# One split point at index 11
# stop_idx: 12
# length of list: 13
# Line: 573
# len([<LINESTRING (134732.206 215848.781, 134833.095 215873.249, 134838.784 215859...>]) line_segments added
# Two split points, at first and last index
# Line: 6029890
# len([<LINESTRING (79737.791 172630.735, 79743.929 172630.757, 79764.038 172634.92...>]) line_segments added
# One split point at index 273
# stop_idx: 274
# length of list: 280
# One split point at index 273
# stop index is 274
# index_list: 1
# stop_idx: 274
# length of list: 280
# Line: 6029895
# len([<LINESTRING (87431.13 178266.537, 87431.951 178274.24, 87437.137 178286.199,...>, <LINESTRING (86519.031 179257.266, 86518.886 179251.681, 86518.862 179246.76...>]) line_segments added
# One split point, at first or last index
# Line: 6029896
# len([<LINESTRING (85660.987 180292.106, 85657.891 180295.916, 85654.319 180299.25...>]) line_segments added
# One split point at index 2
# stop_idx: 3
# length of list: 6
# One split point at index 2
# stop index is 3
# index_list: 1
# stop_idx: 3
# length of list: 6
# Line: 6029897
# len([<LINESTRING (85429.008 181228.11, 85415.242 181244.846, 85397.858 181253.657)>, <LINESTRING (85397.858 181253.657, 85319.039 181304.139, 85284.5 181326.406,...>]) line_segments added
# One split point, at first or last index
# Line: 590
# len([<LINESTRING (136472.204 215653.5, 136523.5 215693.094, 136553.594 215710.094...>]) line_segments added
# First index is a split point, with 5 split points
# Many split points
# stop index is 16
# Super_list: 1
# index_list: 5
# stop_idx: 16
# length of list: 66
# Many split points
# stop index is 35
# Super_list: 2
# index_list: 5
# stop_idx: 35
# length of list: 66
# Many split points
# stop index is 36
# Super_list: 3
# index_list: 5
# stop_idx: 36
# length of list: 66
# Many split points
# stop index is 66
# Super_list: 4
# index_list: 5
# stop_idx: 66
# length of list: 66
# super list still has one more segment to add
# Split point at end of list
# Line: 6029908
# len([<LINESTRING (81349.079 172447.521, 81368.836 172455.099, 81398.205 172468.59...>, <LINESTRING (81536.582 172540.56, 81554.045 172545.058, 81559.274 172552, 81...>, <LINESTRING (81779.735 172759.635, 81810.162 172774.452)>, <LINESTRING (81810.162 172774.452, 81846.41 172777.627, 81863.977 172777.094...>]) line_segments added
# One split point, at first or last index
# Line: 6029915
# len([<LINESTRING (84436.929 175112.298, 84453.146 175138.964, 84446.796 175157.48...>]) line_segments added
# One split point, at first or last index
# Line: 6029920
# len([<LINESTRING (79244.353 176087.404, 79241.594 176090.894, 79239.727 176096.89...>]) line_segments added
# Many split points
# stop index is 9
# Super_list: 1
# index_list: 2
# stop_idx: 9
# length of list: 81
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 69
# Super_list: 3
# index_list: 2
# stop_idx: 69
# length of list: 81
# Line: 6029926
# len([<LINESTRING (82166.352 175565.277, 82167.836 175568.692, 82170.533 175571.46...>, <LINESTRING (82256.787 175635.233, 82249.908 175641.848, 82243.326 175644.86...>, <LINESTRING (82256.787 175635.233, 82249.908 175641.848, 82243.326 175644.86...>]) line_segments added
# One split point at index 52
# stop_idx: 53
# length of list: 77
# One split point at index 52
# stop index is 53
# index_list: 1
# stop_idx: 53
# length of list: 77
# Line: 6029927
# len([<LINESTRING (78193.66 174146.789, 78200.771 174151.767, 78212.413 174158.646...>, <LINESTRING (79181.31 174591.936, 79207.451 174554.365, 79263.898 174584.406...>]) line_segments added
# One split point at index 1
# stop_idx: 2
# length of list: 3
# Line: 6029932
# len([<LINESTRING (82977.812 178300.621, 82977.877 178300.614, 83247.694 178271.567)>]) line_segments added
# First index is a split point, with 3 split points
# Many split points
# stop index is 2
# Super_list: 1
# index_list: 3
# stop_idx: 2
# length of list: 9
# Many split points
# stop index is 6
# Super_list: 2
# index_list: 3
# stop_idx: 6
# length of list: 9
# super list still has one more segment to add
# Last segment added
# Line: 6029934
# len([<LINESTRING (81669.039 177766.805, 81686.368 177777.565)>, <LINESTRING (81686.368 177777.565, 81821.44 177861.432, 81829.241 177866.417...>, <LINESTRING (81907.019 177918.415, 82035.871 178005.132, 82071.677 178029.99...>]) line_segments added
# One split point at index 16
# stop_idx: 17
# length of list: 22
# One split point at index 16
# stop index is 17
# index_list: 1
# stop_idx: 17
# length of list: 22
# Line: 6029935
# len([<LINESTRING (83247.694 178271.567, 83302.795 178264.992, 83352.714 178260.41...>, <LINESTRING (83886.64 178557.39, 83912.359 178616.258, 83951.287 178701.9, 8...>]) line_segments added
# Many split points
# stop index is 12
# Super_list: 1
# index_list: 4
# stop_idx: 12
# length of list: 172
# Many split points
# stop index is 68
# Super_list: 2
# index_list: 4
# stop_idx: 68
# length of list: 172
# Many split points
# stop index is 75
# Super_list: 3
# index_list: 4
# stop_idx: 75
# length of list: 172
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 92
# Super_list: 5
# index_list: 4
# stop_idx: 92
# length of list: 172
# Line: 6029936
# len([<LINESTRING (84634.297 172623.721, 84630.377 172627.461, 84623.123 172636.99...>, <LINESTRING (84537.625 172720.705, 84522.618 172718.293, 84509.054 172711.27...>, <LINESTRING (84288.343 172811.689, 84285.947 172816.961, 84287.384 172822.95...>, <LINESTRING (84264.618 172838.05, 84255.512 172836.372, 84244.249 172830.621...>, <LINESTRING (84264.618 172838.05, 84255.512 172836.372, 84244.249 172830.621...>]) line_segments added
# Two split points, at first and last index
# Line: 6029938
# len([<LINESTRING (82190.246 170953.74, 82161.586 170970.977, 82157.121 170973.781...>]) line_segments added
# One split point at index 2
# stop_idx: 3
# length of list: 7
# One split point at index 2
# stop index is 3
# index_list: 1
# stop_idx: 3
# length of list: 7
# Line: 6029939
# len([<LINESTRING (82621.43 172670.127, 82527.37 172623.461, 82483.758 172602.915)>, <LINESTRING (82483.758 172602.915, 82300.434 172513.44, 82188.292 172457.899...>]) line_segments added
# One split point at index 8
# stop_idx: 9
# length of list: 19
# One split point at index 8
# stop index is 9
# index_list: 1
# stop_idx: 9
# length of list: 19
# Line: 6029941
# len([<LINESTRING (84104.85 172606.33, 84095.525 172610.014, 84083.781 172610.705,...>, <LINESTRING (83979.128 172633.155, 83957.138 172638.797, 83945.165 172643.51...>]) line_segments added
# One split point, at first or last index
# Line: 6029948
# len([<LINESTRING (81587.418 172091.94, 81592.121 172099.161, 81604.946 172123.501...>]) line_segments added
# One split point at index 11
# stop_idx: 12
# length of list: 26
# One split point at index 11
# stop index is 12
# index_list: 1
# stop_idx: 12
# length of list: 26
# Line: 6029950
# len([<LINESTRING (83854.716 172679.07, 83852.282 172683.488, 83845.644 172693.885...>, <LINESTRING (83630.558 172697.726, 83614.792 172689.362, 83602.621 172685.12...>]) line_segments added
# Many split points
# stop index is 2
# Super_list: 1
# index_list: 2
# stop_idx: 2
# length of list: 10
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 7
# Super_list: 3
# index_list: 2
# stop_idx: 7
# length of list: 10
# Line: 6029958
# len([<LINESTRING (79611.119 172598.805, 79596.773 172642.354)>, <LINESTRING (79596.773 172642.354, 79607.529 172647.079, 79622.914 172655.14...>, <LINESTRING (79596.773 172642.354, 79607.529 172647.079, 79622.914 172655.14...>]) line_segments added
# One split point at index 15
# stop_idx: 16
# length of list: 26
# One split point at index 15
# stop index is 16
# index_list: 1
# stop_idx: 16
# length of list: 26
# Line: 650
# len([<LINESTRING (135029.852 215237.97, 135030.46 215245.167, 135027.326 215251.0...>, <LINESTRING (135132.837 215517.084, 135134.042 215507.628, 135134.31 215505....>]) line_segments added
# Many split points
# stop index is 374
# Super_list: 1
# index_list: 3
# stop_idx: 374
# length of list: 604
# Many split points
# stop index is 474
# Super_list: 2
# index_list: 3
# stop_idx: 474
# length of list: 604
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 518
# Super_list: 4
# index_list: 3
# stop_idx: 518
# length of list: 604
# ...
# One split point at index 33
# stop_idx: 34
# length of list: 38
# One split point at index 33
# stop index is 34
# index_list: 1
# stop_idx: 34
# length of list: 38
# Line: 6028753
# len([<LINESTRING (181616.264 189123.253, 181612.493 189120.012, 181605.472 189111...>, <LINESTRING (180980.548 189050.272, 180967.521 189048.134, 180961.403 189051...>]) line_segments added
# Many split points
# stop index is 6
# Super_list: 1
# index_list: 3
# stop_idx: 6
# length of list: 24
# Many split points
# stop index is 7
# Super_list: 2
# index_list: 3
# stop_idx: 7
# length of list: 24
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 12
# Super_list: 4
# index_list: 3
# stop_idx: 12
# length of list: 24
# Line: 6028754
# len([<LINESTRING (187492.131 191148.971, 187488.202 191110.499, 187482.646 191075...>, <LINESTRING (187472.872 190979.905, 187473.544 190976.228)>, <LINESTRING (187473.544 190976.228, 187477.248 190969.613, 187478.435 190968...>, <LINESTRING (187473.544 190976.228, 187477.248 190969.613, 187478.435 190968...>]) line_segments added
# Many split points
# stop index is 24
# Super_list: 1
# index_list: 3
# stop_idx: 24
# length of list: 179
# Many split points
# stop index is 64
# Super_list: 2
# index_list: 3
# stop_idx: 64
# length of list: 179
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 85
# Super_list: 4
# index_list: 3
# stop_idx: 85
# length of list: 179
# Line: 6028758
# len([<LINESTRING (183288.866 189232.553, 183286.349 189232.494, 183274.711 189232...>, <LINESTRING (183073.706 189263.42, 183060.387 189265.602, 183055.124 189264....>, <LINESTRING (182619.589 189259.457, 182616.37 189261.871, 182613.164 189270....>, <LINESTRING (182619.589 189259.457, 182616.37 189261.871, 182613.164 189270....>]) line_segments added
# One split point at index 48
# stop_idx: 49
# length of list: 86
# One split point at index 48
# stop index is 49
# index_list: 1
# stop_idx: 49
# length of list: 86
# Line: 6028762
# len([<LINESTRING (187313.266 190331.167, 187287.216 190318.562, 187286.167 190318...>, <LINESTRING (186638.153 190183.212, 186633.378 190182.034, 186631.648 190180...>]) line_segments added
# One split point, at first or last index
# Line: 6028773
# len([<LINESTRING (180241.095 190367.944, 180318.087 190463.357)>]) line_segments added
# One split point, at first or last index
# Line: 6028810
# len([<LINESTRING (184795.193 188182.754, 184782.595 188180.802, 184771.656 188178...>]) line_segments added
# One split point at index 13
# stop_idx: 14
# length of list: 33
# One split point at index 13
# stop index is 14
# index_list: 1
# stop_idx: 14
# length of list: 33
# Line: 6028811
# len([<LINESTRING (183107.646 188136.463, 183063.791 188119.555, 183009.632 188093...>, <LINESTRING (182768.216 188127.19, 182755.006 188073.824, 182742.642 188025....>]) line_segments added
# One split point, at first or last index
# Line: 6028831
# len([<LINESTRING (177513.219 186643.734, 177553.125 186652.391, 177590.498 186664...>]) line_segments added
# One split point at index 61
# stop_idx: 62
# length of list: 74
# One split point at index 61
# stop index is 62
# index_list: 1
# stop_idx: 62
# length of list: 74
# Line: 6028832
# len([<LINESTRING (180755.289 187595.538, 180779.037 187604, 180811.247 187613.826...>, <LINESTRING (181626.798 187221.174, 181631.422 187209.219, 181643.797 187168...>]) line_segments added
# One split point, at first or last index
# Line: 6028842
# len([<LINESTRING (178873.26 186790.85, 178867.223 186793.405, 178861.463 186798.3...>]) line_segments added
# One split point at index 58
# stop_idx: 59
# length of list: 77
# One split point at index 58
# stop index is 59
# index_list: 1
# stop_idx: 59
# length of list: 77
# Line: 7011902
# len([<LINESTRING (156714.054 174240.399, 156718.469 174239.796, 156718.581 174239...>, <LINESTRING (156978.085 174352.557, 156980.874 174357.972, 156982.338 174362...>]) line_segments added
# One split point at index 39
# stop_idx: 40
# length of list: 46
# One split point at index 39
# stop index is 40
# index_list: 1
# stop_idx: 40
# length of list: 46
# Line: 7011905
# len([<LINESTRING (156034.486 173264.657, 156034.652 173264.822, 156038.303 173266...>, <LINESTRING (156227.88 173509.029, 156230.814 173522.286, 156234.873 173535....>]) line_segments added
# One split point at index 49
# stop_idx: 50
# length of list: 76
# One split point at index 49
# stop index is 50
# index_list: 1
# stop_idx: 50
# length of list: 76
# Line: 7011907
# len([<LINESTRING (155959.981 172880.793, 155959.354 172881.739, 155959.027 172882...>, <LINESTRING (155958.184 173089.337, 155959.559 173095.581, 155959.851 173098...>]) line_segments added
# One split point at index 9
# stop_idx: 10
# length of list: 15
# One split point at index 9
# stop index is 10
# index_list: 1
# stop_idx: 10
# length of list: 15
# Line: 6028890
# len([<LINESTRING (179200.329 186353.469, 179204.873 186257.176, 179247.722 186258...>, <LINESTRING (179297.749 186173.655, 179300.666 186168.43, 179315.961 186107....>]) line_segments added
# Two split points, at first and last index
# Line: 6028899
# len([<LINESTRING (178739.015 186469.293, 178721.078 186461.819, 178680.121 186447...>]) line_segments added
# One split point at index 46
# stop_idx: 47
# length of list: 64
# One split point at index 46
# stop index is 47
# index_list: 1
# stop_idx: 47
# length of list: 64
# Line: 6028926
# len([<LINESTRING (183011.354 187056.337, 182992.484 187043.937, 182981.424 187052...>, <LINESTRING (182721.348 187118.14, 182719.613 187120.604, 182713.529 187130....>]) line_segments added
# One split point, at first or last index
# Line: 6028928
# len([<LINESTRING (178990.708 185792.883, 178989.032 185792.61, 178977.829 185792....>]) line_segments added
# One split point at index 11
# stop_idx: 12
# length of list: 13
# Line: 6028950
# len([<LINESTRING (176908.379 188187.316, 176881.75 188207.328, 176874.141 188214....>]) line_segments added
# First index is a split point, with 4 split points
# Many split points
# stop index is 24
# Super_list: 1
# index_list: 4
# stop_idx: 24
# length of list: 46
# Many split points
# stop index is 28
# Super_list: 2
# index_list: 4
# stop_idx: 28
# length of list: 46
# Many split points
# stop index is 37
# Super_list: 3
# index_list: 4
# stop_idx: 37
# length of list: 46
# super list still has one more segment to add
# Last segment added
# Line: 6028951
# len([<LINESTRING (177205.282 187571.031, 177165.797 187548.312, 177155.36 187546....>, <LINESTRING (176904.86 187517.625, 176845.719 187507.797, 176812.157 187501....>, <LINESTRING (176705.164 187484.841, 176684.672 187495.313, 176674.829 187492...>, <LINESTRING (176537.377 187644.175, 176455.65 187617.472, 176424.351 187615....>]) line_segments added
# One split point, at first or last index
# Line: 6028952
# len([<LINESTRING (176397.547 187560.094, 176383.11 187561.969, 176374.547 187563....>]) line_segments added
# Two split points, at first and last index
# Line: 6028953
# len([<LINESTRING (178786.91 189762.578, 178745.352 189806.113, 178736.357 189815....>]) line_segments added
# One split point, at first or last index
# Line: 6028954
# len([<LINESTRING (178563.054 189966.252, 178538.249 189985.898, 178505.381 190013...>]) line_segments added
# One split point at index 12
# stop_idx: 13
# length of list: 40
# One split point at index 12
# stop index is 13
# index_list: 1
# stop_idx: 13
# length of list: 40
# Line: 6028973
# len([<LINESTRING (175160.942 188845.102, 175156.063 188838.094, 175149.891 188828...>, <LINESTRING (175130.313 188761.688, 175126.157 188744.547, 175124.079 188738...>]) line_segments added
# First index is a split point, with 3 split points
# Many split points
# stop index is 45
# Super_list: 1
# index_list: 3
# stop_idx: 45
# length of list: 251
# Many split points
# stop index is 46
# Super_list: 2
# index_list: 3
# stop_idx: 46
# length of list: 251
# super list still has one more segment to add
# Last segment added
# Line: 6028977
# len([<LINESTRING (175031.155 172678.886, 175024.945 172679.665, 175013.444 172680...>, <LINESTRING (174689.669 172704.725, 174686.136 172704.466)>, <LINESTRING (174686.136 172704.466, 174685.74 172704.361, 174685.472 172704....>]) line_segments added
# Many split points
# stop index is 9
# Super_list: 1
# index_list: 6
# stop_idx: 9
# length of list: 141
# Many split points
# stop index is 59
# Super_list: 2
# index_list: 6
# stop_idx: 59
# length of list: 141
# Many split points
# stop index is 93
# Super_list: 3
# index_list: 6
# stop_idx: 93
# length of list: 141
# Many split points
# stop index is 94
# Super_list: 4
# index_list: 6
# stop_idx: 94
# length of list: 141
# Many split points
# stop index is 109
# Super_list: 5
# index_list: 6
# stop_idx: 109
# length of list: 141
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 127
# Super_list: 7
# index_list: 6
# stop_idx: 127
# length of list: 141
# Line: 6028991
# len([<LINESTRING (174340.883 177606.72, 174345.688 177613.688, 174356.482 177627....>, <LINESTRING (174402.891 177705.141, 174410.438 177724.484, 174415.25 177740....>, <LINESTRING (174388.157 178298.235, 174382.219 178317.297, 174375.985 178338...>, <LINESTRING (174290.094 178723.985, 174292.266 178728.61)>, <LINESTRING (174292.266 178728.61, 174294.25 178735.406, 174293.594 178744.9...>, <LINESTRING (174285.844 178965.891, 174288.875 178991.375, 174290.469 179004...>, <LINESTRING (174285.844 178965.891, 174288.875 178991.375, 174290.469 179004...>]) line_segments added
# One split point at index 78
# stop_idx: 79
# length of list: 81
# One split point at index 78
# stop index is 79
# index_list: 1
# stop_idx: 79
# length of list: 81
# Line: 6028995
# len([<LINESTRING (173172.108 171065.455, 173174.529 171083.791, 173175.006 171095...>, <LINESTRING (173144.026 172787.966, 173150.301 172783.638, 173160.471 172774...>]) line_segments added
# One split point at index 8
# stop_idx: 9
# length of list: 16
# One split point at index 8
# stop index is 9
# index_list: 1
# stop_idx: 9
# length of list: 16
# Line: 6029003
# len([<LINESTRING (174934.788 178946.803, 174999.721 178971.903, 175024.002 178982...>, <LINESTRING (175060.562 179054.297, 175066.564 179054.57, 175076.112 179057....>]) line_segments added
# One split point at index 45
# stop_idx: 46
# length of list: 141
# One split point at index 45
# stop index is 46
# index_list: 1
# stop_idx: 46
# length of list: 141
# Line: 6029013
# len([<LINESTRING (178246.934 177375.571, 178232.041 177390.583, 178200.347 177418...>, <LINESTRING (177785.327 177613.443, 177777.032 177594.708, 177776.987 177594...>]) line_segments added
# Many split points
# stop index is 20
# Super_list: 1
# index_list: 2
# stop_idx: 20
# length of list: 881
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 243
# Super_list: 3
# index_list: 2
# stop_idx: 243
# length of list: 881
# Line: 6029014
# len([<LINESTRING (177546.755 177513.676, 177546.727 177513.673, 177546.47 177513....>, <LINESTRING (177543.836 177513.578, 177543.553 177513.572, 177543.458 177513...>, <LINESTRING (177543.836 177513.578, 177543.553 177513.572, 177543.458 177513...>]) line_segments added
# One split point at index 2
# stop_idx: 3
# length of list: 4
# Line: 6029024
# len([<LINESTRING (174961.441 179184.086, 174947.618 179183.968, 174928.756 179184...>]) line_segments added
# One split point at index 59
# stop_idx: 60
# length of list: 85
# One split point at index 59
# stop index is 60
# index_list: 1
# stop_idx: 60
# length of list: 85
# Line: 6029032
# len([<LINESTRING (166178.709 186811.598, 166173.767 186824.308, 166171.383 186829...>, <LINESTRING (165699.812 187043.439, 165683.155 187037.233, 165678.847 187037...>]) line_segments added
# Two split points, at first and last index
# Line: 6029060
# len([<LINESTRING (150328.453 224014.846, 150316.863 224006.905, 150297.733 223993...>]) line_segments added
# Two split points, at first and last index
# Line: 32524
# len([<LINESTRING (132163.294 172528.285, 132163.456 172528.408, 132166.793 172530...>]) line_segments added
# One split point at index 29
# stop_idx: 30
# length of list: 196
# One split point at index 29
# stop index is 30
# index_list: 1
# stop_idx: 30
# length of list: 196
# Line: 32555
# len([<LINESTRING (132150.846 175905.497, 132150.594 175905.156, 132150.57 175905....>, <LINESTRING (132063.813 175707.016, 132063.751 175707, 132063.672 175706.953...>]) line_segments added
# One split point at index 11
# stop_idx: 12
# length of list: 34
# One split point at index 11
# stop index is 12
# index_list: 1
# stop_idx: 12
# length of list: 34
# Line: 32561
# len([<LINESTRING (132651.907 176872.422, 132649 176871.344, 132646.891 176866.11,...>, <LINESTRING (132561.094 176790.985, 132444.75 176657.562, 132438.5 176648.70...>]) line_segments added
# Many split points
# stop index is 4
# Super_list: 1
# index_list: 3
# stop_idx: 4
# length of list: 159
# Many split points
# stop index is 11
# Super_list: 2
# index_list: 3
# stop_idx: 11
# length of list: 159
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 82
# Super_list: 4
# index_list: 3
# stop_idx: 82
# length of list: 159
# Line: 32565
# len([<LINESTRING (131850.907 177536.5, 131846.047 177530.256, 131859.594 177407.9...>, <LINESTRING (131888.624 177412.88, 131893.319 177404.107, 131903.77 177363.0...>, <LINESTRING (131878.238 177292.105, 131869.639 177276.362, 131866.36 177274....>, <LINESTRING (131878.238 177292.105, 131869.639 177276.362, 131866.36 177274....>]) line_segments added
# Many split points
# stop index is 198
# Super_list: 1
# index_list: 2
# stop_idx: 198
# length of list: 413
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 293
# Super_list: 3
# index_list: 2
# stop_idx: 293
# length of list: 413
# Line: 32575
# len([<LINESTRING (133941.141 174790.406, 133918.47 174780.271, 133918.407 174780....>, <LINESTRING (133468.876 175250.703, 133441.827 175263.887, 133441.798 175263...>, <LINESTRING (133468.876 175250.703, 133441.827 175263.887, 133441.798 175263...>]) line_segments added
# First index is a split point, with 4 split points
# Many split points
# stop index is 17
# Super_list: 1
# index_list: 4
# stop_idx: 17
# length of list: 32
# Many split points
# stop index is 29
# Super_list: 2
# index_list: 4
# stop_idx: 29
# length of list: 32
# Many split points
# stop index is 32
# Super_list: 3
# index_list: 4
# stop_idx: 32
# length of list: 32
# super list still has one more segment to add
# Split point at end of list
# Line: 32592
# len([<LINESTRING (133522.797 177153.063, 133566.985 177170.266, 133582.594 177161...>, <LINESTRING (133820.876 176859.844, 133793.469 176828.688, 133798.173 176826...>, <LINESTRING (133873.544 176774.81, 133883.863 176763.856, 133886.561 176757....>]) line_segments added
# Two split points, at first and last index
# Line: 32599
# len([<LINESTRING (135246.495 176530.13, 135241.777 176527.261, 135238.734 176525....>]) line_segments added
# Many split points
# stop index is 15
# Super_list: 1
# index_list: 3
# stop_idx: 15
# length of list: 37
# Many split points
# stop index is 18
# Super_list: 2
# index_list: 3
# stop_idx: 18
# length of list: 37
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 19
# Super_list: 4
# index_list: 3
# stop_idx: 19
# length of list: 37
# Line: 7012201
# len([<LINESTRING (70771.79 219738.797, 70772.477 219738.531, 70773.469 219740.156...>, <LINESTRING (70851.899 219748.625, 70855.516 219745.61, 70880.235 219738.219...>, <LINESTRING (70886.86 219736.109, 70890.328 219736.109, 70895.602 219738.531...>, <LINESTRING (70886.86 219736.109, 70890.328 219736.109)>]) line_segments added
# Two split points, at first and last index
# Line: 32672
# len([<LINESTRING (138704.147 176812.61, 138688.06 176822.559, 138674.937 176829.5...>]) line_segments added
# Many split points
# stop index is 12
# Super_list: 1
# index_list: 2
# stop_idx: 12
# length of list: 21
# super list still has one more segment to add
# Last segment added
# Many split points
# stop index is 16
# Super_list: 3
# index_list: 2
# stop_idx: 16
# length of list: 21
# Line: 6029276
# len([<LINESTRING (161243.92 186896.994, 161230.637 186906.472, 160956.136 187101....>, <LINESTRING (159618.409 188060.371, 159396.076 188219.358, 159199.826 188362...>, <LINESTRING (159618.409 188060.371, 159396.076 188219.358, 159199.826 188362...>]) line_segments added
# 15215
# 15215
# (15215, 2)
# EPSG:31370
# Time taken: 50.69303607940674
# ********************************************************

# %%
splitlines_df2 = splitlines_df.drop_duplicates(subset='geometry')
splitlines_df2.shape
# Out:
# (15153, 2)

# %%
# splitlines_df2.to_file('../data/test_data/test_split_full_4.shp')

# %%
splitlines_df2.VHAS.isna().sum()
# Out:
# 0

# %%
splitlines_df2
# Out:
#                                                 geometry     VHAS
# index
# 0      LINESTRING (138979.165 172375.119, 138977.345 ...    32768
# 1      LINESTRING (138977.309 172382.827, 138977.282 ...    32768
# 2      LINESTRING (139426.094 170006.797, 139438.876 ...    32776
# 3      LINESTRING (139710.263 170419.798, 139711.638 ...    32776
# 4      LINESTRING (138841.797 171003.798, 138847.552 ...    32784
# ...                                                  ...      ...
# 15210  LINESTRING (70886.860 219736.109, 70890.328 21...  7012201
# 15211  LINESTRING (138704.147 176812.610, 138688.060 ...    32672
# 15212  LINESTRING (161243.920 186896.994, 161230.637 ...  6029276
# 15213  LINESTRING (159618.409 188060.371, 159396.076 ...  6029276
# 15214  LINESTRING (159618.409 188060.371, 159396.076 ...  6029276
#
# [15153 rows x 2 columns]

# %% [markdown]
# **Assign new water line ids to the new split segments**

# %%
# get unique line segments ids
def get_unique_ID(df, col):
    """Get unique ID for each new split segment in a dataframe
    Assert that the number of unique IDs is equal to the number of split segments
    """
    # the new split lines need a new unique uniqueID value
    df["num_id"] = df.groupby(col).cumcount() + 1
    df["new_string_id"] = df[col].astype(str) + "_" + df["num_id"].astype(str)

    # df = df.drop(columns=['num_id', col]).rename(columns={'new_string_id': col})
    # assert df[col].nunique() == len(df)

    return df

splitlines_vhas = get_unique_ID(splitlines_df2, "VHAS")
assert len(splitlines_vhas) == splitlines_vhas.new_string_id.nunique()

# %%
splitlines_vhas
# Out:
#                                                 geometry     VHAS  num_id  \
# index
# 0      LINESTRING (138979.165 172375.119, 138977.345 ...    32768       1
# 1      LINESTRING (138977.309 172382.827, 138977.282 ...    32768       2
# 2      LINESTRING (139426.094 170006.797, 139438.876 ...    32776       1
# 3      LINESTRING (139710.263 170419.798, 139711.638 ...    32776       2
# 4      LINESTRING (138841.797 171003.798, 138847.552 ...    32784       1
# ...                                                  ...      ...     ...
# 15210  LINESTRING (70886.860 219736.109, 70890.328 21...  7012201       4
# 15211  LINESTRING (138704.147 176812.610, 138688.060 ...    32672       1
# 15212  LINESTRING (161243.920 186896.994, 161230.637 ...  6029276       1
# 15213  LINESTRING (159618.409 188060.371, 159396.076 ...  6029276       2
# 15214  LINESTRING (159618.409 188060.371, 159396.076 ...  6029276       3
#
#       new_string_id                                             coords
# index
# 0           32768_1  [(138979.16464000044, 172375.1191999782), (138...
# 1           32768_2  [(138977.30854000003, 172382.8270999808), (138...
# 2           32776_1  [(139426.09394000322, 170006.7971999785), (139...
# 3           32776_2  [(139710.26303999725, 170419.79849998187), (13...
# 4           32784_1  [(138841.79733999673, 171003.7978999773), (138...
# ...             ...                                                ...
# 15210     7012201_4  [(70886.85953999906, 219736.1094999779), (7089...
# 15211       32672_1  [(138704.14674000297, 176812.61049997993), (13...
# 15212     6029276_1  [(161243.91973999736, 186896.99359998107), (16...
# 15213     6029276_2  [(159618.40934000016, 188060.37079997826), (15...
# 15214     6029276_3  [(159618.40934000016, 188060.37079997826), (15...
#
# [15153 rows x 5 columns]

# %%
#![5.split_segments2.PNG](attachment:5.split_segments2.PNG)

# %%
# splitlines_vhas.to_file('../data/test_data2/splitlines_vhas3.shp')
# splitlines_df_upload.to_file(r"data_transform\vl_water_segments_PROCESSED.shp")

# %% [markdown]
# ## Combine Nodes
#
# Combine the original water nodes, and the new water nodes which are the split points used in the previous operation.

# %%
print(water_nodes_df.head())
# assert len(water_nodes_df) == water_nodes_df.geometry.nunique()
# Out:
#                         geometry node_id      source
# 0  POINT (177317.033 187108.927)  VL_HN1  water_node
# 1  POINT (175948.922 187590.860)  VL_HN2  water_node
# 2  POINT (168312.751 188947.734)  VL_HN3  water_node
# 3  POINT (190287.875 162834.403)  VL_HN4  water_node
# 4  POINT (177620.500 182754.219)  VL_HN5  water_node

# %%
water_nodes_df["source"] = "water_node"

connection_nodes = (
    connection_nodes_gdf[["CODEKOPPNT", "geometry"]]
    .rename(columns={"CODEKOPPNT": "node_id"})
    .assign(source="connection_node")
)

nodes_combined = (
    pd.concat([water_nodes_df, connection_nodes])
    .drop_duplicates(subset="geometry", keep="first")
    .reset_index(drop=True)
)

print(connection_nodes.shape)
connection_nodes.head()
# Out:
# (11699, 3)
#          node_id                       geometry           source
# 0  24195613725_1   POINT (49720.629 215107.628)  connection_node
# 1      7165620_1   POINT (63142.133 172229.301)  connection_node
# 2      7166026_1   POINT (61256.557 172127.427)  connection_node
# 3      7165606_1   POINT (65981.594 174958.909)  connection_node
# 4      7170009_1  POINT (222673.313 204101.625)  connection_node

# %%
nodes_combined
# Out:
#                             geometry    node_id           source
# 0      POINT (177317.033 187108.927)     VL_HN1       water_node
# 1      POINT (175948.922 187590.860)     VL_HN2       water_node
# 2      POINT (168312.751 188947.734)     VL_HN3       water_node
# 3      POINT (190287.875 162834.403)     VL_HN4       water_node
# 4      POINT (177620.500 182754.219)     VL_HN5       water_node
# ...                              ...        ...              ...
# 69755  POINT (221539.327 180803.419)  6002935_1  connection_node
# 69756  POINT (218308.622 189506.152)  7184778_1  connection_node
# 69757  POINT (224393.703 184071.719)  7177561_1  connection_node
# 69758  POINT (217762.589 183421.889)  6003589_1  connection_node
# 69759  POINT (212127.060 199159.382)  7169137_1  connection_node
#
# [69760 rows x 3 columns]

# %%
nodes_combined2 = nodes_combined.drop_duplicates(subset='geometry')
nodes_combined2.shape
# Out:
# (69760, 3)

# %%
def add_sewernode_id(row):
    if row["source"] == "connection_node":
        return row["node_id"]
    else:
        return None


def get_water_nodes(df, prefix):
    df["sewernode_id"] = df.apply(add_sewernode_id, axis=1)

    conn_df = df[df["source"] == "connection_node"]
    water_nodes = df.loc[df["source"] == "water_node"]

    nodes_list = water_nodes["node_id"].to_list()
    start_num = max([int(i[len(prefix) + 3:]) for i in nodes_list])

    diff = len(df.index) - len(water_nodes_df.index)

    conn_df["node_id"] = range((start_num + 1), (start_num + diff + 1))
    conn_df["node_id"] = (prefix + '_HN') + conn_df["node_id"].astype(str)

    nodes_all = pd.concat([water_nodes, conn_df])
    nodes_all_gdf = gpd.GeoDataFrame(nodes_all, geometry="geometry", crs=PROJ_CRS)

    return nodes_all_gdf

waternodes = get_water_nodes(nodes_combined, "VL")
waternodes
# Out:
#                             geometry     node_id           source sewernode_id
# 0      POINT (177317.033 187108.927)      VL_HN1       water_node         None
# 1      POINT (175948.922 187590.860)      VL_HN2       water_node         None
# 2      POINT (168312.751 188947.734)      VL_HN3       water_node         None
# 3      POINT (190287.875 162834.403)      VL_HN4       water_node         None
# 4      POINT (177620.500 182754.219)      VL_HN5       water_node         None
# ...                              ...         ...              ...          ...
# 69755  POINT (221539.327 180803.419)  VL_HN69756  connection_node    6002935_1
# 69756  POINT (218308.622 189506.152)  VL_HN69757  connection_node    7184778_1
# 69757  POINT (224393.703 184071.719)  VL_HN69758  connection_node    7177561_1
# 69758  POINT (217762.589 183421.889)  VL_HN69759  connection_node    6003589_1
# 69759  POINT (212127.060 199159.382)  VL_HN69760  connection_node    7169137_1
#
# [69760 rows x 4 columns]

# %%
final_water_nodes = (
    waternodes.merge(
        merged_sewer_nodes[["STATUS", "LBLTYPE", "NRKPNT"]],
        left_on="sewernode_id",
        right_on="NRKPNT",
        how="left",
    )
    .drop('NRKPNT', axis=1)
    .drop_duplicates(subset="geometry", keep="first")
    .reset_index(drop=True)
)

# %%
final_water_nodes
# Out:
#                             geometry     node_id           source  \
# 0      POINT (177317.033 187108.927)      VL_HN1       water_node
# 1      POINT (175948.922 187590.860)      VL_HN2       water_node
# 2      POINT (168312.751 188947.734)      VL_HN3       water_node
# 3      POINT (190287.875 162834.403)      VL_HN4       water_node
# 4      POINT (177620.500 182754.219)      VL_HN5       water_node
# ...                              ...         ...              ...
# 69755  POINT (221539.327 180803.419)  VL_HN69756  connection_node
# 69756  POINT (218308.622 189506.152)  VL_HN69757  connection_node
# 69757  POINT (224393.703 184071.719)  VL_HN69758  connection_node
# 69758  POINT (217762.589 183421.889)  VL_HN69759  connection_node
# 69759  POINT (212127.060 199159.382)  VL_HN69760  connection_node
#
#       sewernode_id   STATUS  LBLTYPE
# 0             None      NaN      NaN
# 1             None      NaN      NaN
# 2             None      NaN      NaN
# 3             None      NaN      NaN
# 4             None      NaN      NaN
# ...            ...      ...      ...
# 69755    6002935_1   Actief  Uitlaat
# 69756    7184778_1  Gepland  Uitlaat
# 69757    7177561_1   Actief  Uitlaat
# 69758    6003589_1   Actief  Uitlaat
# 69759    7169137_1   Actief  Uitlaat
#
# [69760 rows x 6 columns]

# %%
# final_water_nodes.to_file(config.data_dest / "vl_nodes_PROCESSED.shp")
# Out:
# C:\Users\u0119822\AppData\Local\Temp\ipykernel_23076\3649228899.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   final_water_nodes.to_file(config.data_dest / "vl_nodes_PROCESSED.shp")

# %%
final_water_nodes.crs
# Out:
# <Derived Projected CRS: EPSG:31370>
# Name: BD72 / Belgian Lambert 72
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Belgium - onshore.
# - bounds: (2.5, 49.5, 6.4, 51.51)
# Coordinate Operation:
# - name: Belgian Lambert 72
# - method: Lambert Conic Conformal (2SP)
# Datum: Reseau National Belge 1972
# - Ellipsoid: International 1924
# - Prime Meridian: Greenwich

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#    print(merged_nodes)

# merged_nodes.to_file(r"data_transform\vl_nodes_combined_V02.shp")
# merged_nodes.to_file(data_dest / "vl_nodes_combined_V02.shp")

# %% [markdown]
# ## Get start and end IDs for the line segments, to include new connection nodes

# %%
def line_segments_start_end_ids(splitlines_df, all_nodes_gdf, node_id, PROJ_CRS):
    """Returns the start and end ids of the line segments for a given node id"""
    splitlines_df["coords"] = splitlines_df.apply(
        lambda row: get_line_coords(row.geometry), axis=1
    )  #%time
    all_nodes_gdf["coords"] = get_point_coords(all_nodes_gdf)
    # join linestrings to the nearest node, in this case the node attached to the line
    joined_lines_nodes = gpd.sjoin_nearest(
        splitlines_df, all_nodes_gdf, how="left"
    ).reset_index()
    print(joined_lines_nodes.shape)
    print(joined_lines_nodes['source'].value_counts())
    # identify the nodes that corresponding to the line start and end points
    idx_start = []
    start_id = []
    idx_end = []
    end_id = []

    for idx, row in joined_lines_nodes.iterrows():
        if row.coords_right == row.coords_left[0]:
            idx_start.append(row["index"])
            start_id.append(row[node_id])
        elif row.coords_right == row.coords_left[-1]:
            idx_end.append(row["index"])
            end_id.append(row[node_id])

    start_id_df = (
        pd.DataFrame({"line_index": idx_start, f"start_{node_id}": start_id})
        .merge(
            joined_lines_nodes[["index", node_id, "VHAS", "geometry"]],
            left_on="line_index",
            right_on="index",
            how="left",
        )
        .drop_duplicates("geometry")
    )
    print(start_id_df.shape)
    end_id_df = (
        pd.DataFrame({"line_index": idx_end, f"end_{node_id}": end_id})
        .merge(
            joined_lines_nodes[["index", node_id, "VHAS", "geometry"]],
            left_on="line_index",
            right_on="index",
            how="left",
        )
        .drop_duplicates("geometry")
    )
    print(end_id_df.shape)
    merged_start_end_df = (
        pd.merge(start_id_df, end_id_df, on="geometry", how="outer")
        .drop(
            [
                "line_index_x",
                "index_x",
                "node_id_x",
                "index_y",
                "line_index_y",
                "node_id_y",
                "VHAS_x",
            ],
            axis=1,
        )
        .rename(columns={"start_node_id": "start_ID", "end_node_id": "end_ID"})
    )

    return gpd.GeoDataFrame(merged_start_end_df, geometry="geometry", crs=PROJ_CRS)

# %%
splitlines_vhas.shape
# Out:
# (15153, 5)

# %%
waternodes.columns
# Out:
# Index(['geometry', 'node_id', 'source', 'sewernode_id'], dtype='object')

# %%
node_id = "node_id"
splitlines_with_ids = line_segments_start_end_ids(
    splitlines_vhas, waternodes[["geometry", "source", "node_id"]], node_id, PROJ_CRS
)
# Out:
# (32523, 10)
# connection_node    18817
# water_node         13706
# Name: source, dtype: int64
# (15153, 6)
# (15153, 6)

# %%
splitlines_with_ids
# Out:
#          start_ID                                           geometry  \
# 0      VL_HN55957  LINESTRING (138979.165 172375.119, 138977.345 ...
# 1      VL_HN66013  LINESTRING (138977.309 172382.827, 138977.282 ...
# 2        VL_HN579  LINESTRING (139426.094 170006.797, 139438.876 ...
# 3      VL_HN67674  LINESTRING (139710.263 170419.798, 139711.638 ...
# 4      VL_HN22837  LINESTRING (138841.797 171003.798, 138847.552 ...
# ...           ...                                                ...
# 15148  VL_HN64258  LINESTRING (70886.860 219736.109, 70890.328 21...
# 15149  VL_HN34681  LINESTRING (138704.147 176812.610, 138688.060 ...
# 15150  VL_HN25143  LINESTRING (161243.920 186896.994, 161230.637 ...
# 15151  VL_HN66511  LINESTRING (159618.409 188060.371, 159396.076 ...
# 15152  VL_HN66511  LINESTRING (159618.409 188060.371, 159396.076 ...
#
#            end_ID   VHAS_y
# 0      VL_HN66013    32768
# 1      VL_HN42790    32768
# 2      VL_HN67674    32776
# 3        VL_HN580    32776
# 4      VL_HN65514    32784
# ...           ...      ...
# 15148  VL_HN64257  7012201
# 15149  VL_HN29689    32672
# 15150  VL_HN66511  6029276
# 15151  VL_HN58124  6029276
# 15152  VL_HN66513  6029276
#
# [15153 rows x 4 columns]

# %% [markdown]
# **Get unique water line ids**

# %%
# get unique line segments ids
def get_unique_ID(df, col):
    """Get unique ID for each new split segment in a dataframe
    Assert that the number of unique IDs is equal to the number of split segments
    """
    # the new split lines need a new unique uniqueID value
    df["num_id"] = df.groupby(col).cumcount() + 1
    df["new_string_id"] = df[col].astype(str) + "_" + df["num_id"].astype(str)

    # df = df.drop(columns=['num_id', col]).rename(columns={'new_string_id': col})
    # assert df[col].nunique() == len(df)

    return df

splitlines_vhas = get_unique_ID(splitlines_with_ids, "VHAS_y")
assert len(splitlines_vhas) == splitlines_vhas.new_string_id.nunique()

# %%
splitlines_with_ids
# Out:
#          start_ID                                           geometry  \
# 0      VL_HN55957  LINESTRING (138979.165 172375.119, 138977.345 ...
# 1      VL_HN66013  LINESTRING (138977.309 172382.827, 138977.282 ...
# 2        VL_HN579  LINESTRING (139426.094 170006.797, 139438.876 ...
# 3      VL_HN67674  LINESTRING (139710.263 170419.798, 139711.638 ...
# 4      VL_HN22837  LINESTRING (138841.797 171003.798, 138847.552 ...
# ...           ...                                                ...
# 15148  VL_HN64258  LINESTRING (70886.860 219736.109, 70890.328 21...
# 15149  VL_HN34681  LINESTRING (138704.147 176812.610, 138688.060 ...
# 15150  VL_HN25143  LINESTRING (161243.920 186896.994, 161230.637 ...
# 15151  VL_HN66511  LINESTRING (159618.409 188060.371, 159396.076 ...
# 15152  VL_HN66511  LINESTRING (159618.409 188060.371, 159396.076 ...
#
#            end_ID   VHAS_y  num_id new_string_id
# 0      VL_HN66013    32768       1       32768_1
# 1      VL_HN42790    32768       2       32768_2
# 2      VL_HN67674    32776       1       32776_1
# 3        VL_HN580    32776       2       32776_2
# 4      VL_HN65514    32784       1       32784_1
# ...           ...      ...     ...           ...
# 15148  VL_HN64257  7012201       4     7012201_4
# 15149  VL_HN29689    32672       1       32672_1
# 15150  VL_HN66511  6029276       1     6029276_1
# 15151  VL_HN58124  6029276       2     6029276_2
# 15152  VL_HN66513  6029276       3     6029276_3
#
# [15153 rows x 6 columns]

# %%
splitlines_vhas = get_unique_ID(splitlines_with_ids, "VHAS_y")
assert len(splitlines_vhas) == splitlines_vhas.new_string_id.nunique()

# %%
splitlines_vhas
# Out:
#          start_ID                                           geometry  \
# 0      VL_HN55957  LINESTRING (138979.165 172375.119, 138977.345 ...
# 1      VL_HN66013  LINESTRING (138977.309 172382.827, 138977.282 ...
# 2        VL_HN579  LINESTRING (139426.094 170006.797, 139438.876 ...
# 3      VL_HN67674  LINESTRING (139710.263 170419.798, 139711.638 ...
# 4      VL_HN22837  LINESTRING (138841.797 171003.798, 138847.552 ...
# ...           ...                                                ...
# 15148  VL_HN64258  LINESTRING (70886.860 219736.109, 70890.328 21...
# 15149  VL_HN34681  LINESTRING (138704.147 176812.610, 138688.060 ...
# 15150  VL_HN25143  LINESTRING (161243.920 186896.994, 161230.637 ...
# 15151  VL_HN66511  LINESTRING (159618.409 188060.371, 159396.076 ...
# 15152  VL_HN66511  LINESTRING (159618.409 188060.371, 159396.076 ...
#
#            end_ID   VHAS_y  num_id new_string_id
# 0      VL_HN66013    32768       1       32768_1
# 1      VL_HN42790    32768       2       32768_2
# 2      VL_HN67674    32776       1       32776_1
# 3        VL_HN580    32776       2       32776_2
# 4      VL_HN65514    32784       1       32784_1
# ...           ...      ...     ...           ...
# 15148  VL_HN64257  7012201       4     7012201_4
# 15149  VL_HN29689    32672       1       32672_1
# 15150  VL_HN66511  6029276       1     6029276_1
# 15151  VL_HN58124  6029276       2     6029276_2
# 15152  VL_HN66513  6029276       3     6029276_3
#
# [15153 rows x 6 columns]

# %%
splitlines_final = (
    splitlines_vhas.merge(water_final, left_on="VHAS_y", right_on="VHAS", how="left")
    .drop(["VHAS_y", "VHAS", "num_id", "start_ID_y", "end_ID_y", "geometry_y"], axis=1)
    .rename(
        columns={
            "new_string_id": "VHAS",
            "start_ID_x": "start_ID",
            "end_ID_x": "end_ID",
            "geometry_x": "geometry",
        }
    )
)

# assert splitlines_merged.VHAS_x.all() == splitlines_merged.VHAS.all()

# %%
splitlines_final.head(3)
# Out:
#      start_ID                                           geometry      end_ID  \
# 0  VL_HN55957  LINESTRING (138979.165 172375.119, 138977.345 ...  VL_HN66013
# 1  VL_HN66013  LINESTRING (138977.309 172382.827, 138977.282 ...  VL_HN42790
# 2    VL_HN579  LINESTRING (139426.094 170006.797, 139438.876 ...  VL_HN67674
#
#       VHAS   OIDN    UIDN  VHAG             NAAM REGCODE REGCODE1  ... CATC  \
# 0  32768_1  44659  723201  6200         Zierbeek   B5111      NaN  ...    2
# 1  32768_2  44659  723201  6200         Zierbeek   B5111      NaN  ...    2
# 2  32776_1  44660  664399  6243  Peverstraatbeek   B5114      NaN  ...    2
#
#                          LBLCATC BEKNR       BEKNAAM  STRMGEB GEO  \
# 0  Geklasseerd, tweede categorie     7  Denderbekken  Schelde   2
# 1  Geklasseerd, tweede categorie     7  Denderbekken  Schelde   2
# 2  Geklasseerd, tweede categorie     7  Denderbekken  Schelde   1
#
#            LBLGEO VHAZONENR WTRLICHC  LENGTE
# 0        < 0.25 m       422      213  866.12
# 1        < 0.25 m       422      213  866.12
# 2  2.5 tot 0.25 m       422     1033  952.75
#
# [3 rows x 21 columns]

# %%
splitlines_final.shape
# Out:
# (15153, 21)

# %% [markdown]
# ## Gather all linestrings into one dataset
#
# With the split segments now joined to the water dataset to get the necessary attributes, we can now combine all the linestrings into one dataset.

# %%
def merge_segments_to_water(split_segments, split_segments_final, water_df, col):
    """This function merges segments to water polygons"""
    # drop the linestrings to be split and merge the df with split lines
    # water_final_str = water_final_str.astype({"VHAS": str}, errors='raise')

    split_segments = split_segments.astype({col: str}, errors="raise")
    split_segments_final = split_segments_final.astype({col: str}, errors="raise")
    water_df = water_df.astype({col: str}, errors="raise")
    print("water_df: ", len(water_df))

    assert split_segments_final[col].nunique() == split_segments_final["geometry"].nunique()
    assert water_df[col].nunique() == water_df["geometry"].nunique()

    linestrings_to_drop = list(set(split_segments[col].to_list()))
    print("linestrings_to_drop: ", len(linestrings_to_drop))
    print("split_segments: ", len(split_segments))

    water_df_trimmed = water_df.query(
        col + " not in @linestrings_to_drop"
    )  # .reset_index(drop=True)
    water_df_drop = water_df.query(col + " in @linestrings_to_drop")
    # assert water_df_trimmed[col].nunique() == water_df_trimmed['geometry'].nunique()
    # print("water df trimmed: ", len(water_df_trimmed))
    # print("water df drop: ", len(water_df_drop))

    # merge the split lines with the original water lines
    # water_df_trimmed_merged = water_df_trimmed.merge(split_segments_line_ids, on=col, how='outer')
    merged_df = gpd.GeoDataFrame(
        pd.concat([split_segments_final, water_df_trimmed], ignore_index=True),
        geometry="geometry",
        crs=PROJ_CRS,
    )
    print("merged df: ", len(merged_df))
    
    assert merged_df["geometry"].nunique() == merged_df[col].nunique()
    assert (len(water_df) - len(linestrings_to_drop)) + len(split_segments) == len(merged_df)

    # assert merged_df['geometry'].nunique() == merged_df[col].nunique()
    return merged_df

# %%
splitlines_vhas
# Out:
#          start_ID                                           geometry  \
# 0      VL_HN55957  LINESTRING (138979.165 172375.119, 138977.345 ...
# 1      VL_HN66013  LINESTRING (138977.309 172382.827, 138977.282 ...
# 2        VL_HN579  LINESTRING (139426.094 170006.797, 139438.876 ...
# 3      VL_HN67674  LINESTRING (139710.263 170419.798, 139711.638 ...
# 4      VL_HN22837  LINESTRING (138841.797 171003.798, 138847.552 ...
# ...           ...                                                ...
# 15148  VL_HN64258  LINESTRING (70886.860 219736.109, 70890.328 21...
# 15149  VL_HN34681  LINESTRING (138704.147 176812.610, 138688.060 ...
# 15150  VL_HN25143  LINESTRING (161243.920 186896.994, 161230.637 ...
# 15151  VL_HN66511  LINESTRING (159618.409 188060.371, 159396.076 ...
# 15152  VL_HN66511  LINESTRING (159618.409 188060.371, 159396.076 ...
#
#            end_ID   VHAS_y  num_id new_string_id
# 0      VL_HN66013    32768       1       32768_1
# 1      VL_HN42790    32768       2       32768_2
# 2      VL_HN67674    32776       1       32776_1
# 3        VL_HN580    32776       2       32776_2
# 4      VL_HN65514    32784       1       32784_1
# ...           ...      ...     ...           ...
# 15148  VL_HN64257  7012201       4     7012201_4
# 15149  VL_HN29689    32672       1       32672_1
# 15150  VL_HN66511  6029276       1     6029276_1
# 15151  VL_HN58124  6029276       2     6029276_2
# 15152  VL_HN66513  6029276       3     6029276_3
#
# [15153 rows x 6 columns]

# %%
splitlines_df = splitlines_vhas[['VHAS_y', 'geometry']].rename(columns={'VHAS_y':'VHAS'})

# %%
segments_to_water = merge_segments_to_water(
    splitlines_df, splitlines_final, water_final, "VHAS"
)
# Out:
# water_df:  63762
# linestrings_to_drop:  6846
# split_segments:  15153
# merged df:  72069

# %%
segments_to_water.head()
# Out:
#      start_ID                                           geometry      end_ID  \
# 0  VL_HN55957  LINESTRING (138979.165 172375.119, 138977.345 ...  VL_HN66013
# 1  VL_HN66013  LINESTRING (138977.309 172382.827, 138977.282 ...  VL_HN42790
# 2    VL_HN579  LINESTRING (139426.094 170006.797, 139438.876 ...  VL_HN67674
# 3  VL_HN67674  LINESTRING (139710.263 170419.798, 139711.638 ...    VL_HN580
# 4  VL_HN22837  LINESTRING (138841.797 171003.798, 138847.552 ...  VL_HN65514
#
#       VHAS   OIDN    UIDN  VHAG             NAAM REGCODE REGCODE1  ... CATC  \
# 0  32768_1  44659  723201  6200         Zierbeek   B5111      NaN  ...    2
# 1  32768_2  44659  723201  6200         Zierbeek   B5111      NaN  ...    2
# 2  32776_1  44660  664399  6243  Peverstraatbeek   B5114      NaN  ...    2
# 3  32776_2  44660  664399  6243  Peverstraatbeek   B5114      NaN  ...    2
# 4  32784_1  44567  687269  6258          Zibbeek   B5116      NaN  ...    2
#
#                          LBLCATC BEKNR       BEKNAAM  STRMGEB GEO  \
# 0  Geklasseerd, tweede categorie     7  Denderbekken  Schelde   2
# 1  Geklasseerd, tweede categorie     7  Denderbekken  Schelde   2
# 2  Geklasseerd, tweede categorie     7  Denderbekken  Schelde   1
# 3  Geklasseerd, tweede categorie     7  Denderbekken  Schelde   1
# 4  Geklasseerd, tweede categorie     7  Denderbekken  Schelde   1
#
#            LBLGEO VHAZONENR WTRLICHC  LENGTE
# 0        < 0.25 m       422      213  866.12
# 1        < 0.25 m       422      213  866.12
# 2  2.5 tot 0.25 m       422     1033  952.75
# 3  2.5 tot 0.25 m       422     1033  952.75
# 4  2.5 tot 0.25 m       422     1033  781.83
#
# [5 rows x 21 columns]

# %%
segments_to_water.geometry.nunique()
# Out:
# 72069

# %% [markdown]
# **Recalculate the length of the new linestrings**

# %%
segments_to_water["LENGTE"] = segments_to_water["geometry"].apply(
    lambda x: x.length
)

# %%
segments_to_water.columns
# Out:
# Index(['start_ID', 'geometry', 'end_ID', 'VHAS', 'OIDN', 'UIDN', 'VHAG',
#        'NAAM', 'REGCODE', 'REGCODE1', 'BEHEER', 'CATC', 'LBLCATC', 'BEKNR',
#        'BEKNAAM', 'STRMGEB', 'GEO', 'LBLGEO', 'VHAZONENR', 'WTRLICHC',
#        'LENGTE'],
#       dtype='object')

# %%
segments_to_water2 = (segments_to_water.rename
                                        (columns={'LBLCATC':'category',
                                        'end_ID':'end_ID', 
                                        'VHAS': 'line_id',
                                        'LENGTE': 'length',
                                        'start_ID':'start_ID', 
                                        'STRMGEB':'basin',
                                        'NAAM':'line_name'
                                        }))

# %%
# segments_to_water2.to_file(config.data_dest / "vl_water_PROCESSED.shp")

# %% [markdown]
# ### Intermodal network connection object

# %% [markdown]
# An intermodal network connection object is a link object between the water network and the sewer network.

# %%
network_connection_object = (
    final_water_nodes[["node_id", "sewernode_id", "geometry"]]
    .query("sewernode_id.notnull()")
    .rename(columns={"node_id": "hydronode_id"})
    .reset_index(drop=True)
)

# %%
network_connection_object.head(2)
# Out:
#   hydronode_id   sewernode_id                      geometry
# 0   VL_HN60772  24195613725_1  POINT (49720.629 215107.628)
# 1   VL_HN60773      7165620_1  POINT (63142.133 172229.301)

# %%
network_conn2 = network_connection_object.merge(ext_nodes_df[["CODEKOPPNT", "geometry"]], left_on="sewernode_id", right_on="CODEKOPPNT", how="left")

def make_connection_lines(df, from_point, to_point):
    lines = []
    for index, row in df.iterrows():
        p_1 = Point(row[from_point])
        p_2 = Point(row[to_point])
        intersect = LineString([p_1, p_2])
        # linestring = loads(intersect)
        lines.append(intersect)
    return lines

network_conn2['connection_lines'] = make_connection_lines(network_conn2, 'geometry_x', 'geometry_y')
network_conn2.head(2)


connection_links = gpd.GeoDataFrame(network_conn2[["hydronode_id", "sewernode_id", "connection_lines"]]
                    .rename(columns={"hydronode_id":"idElement1", "sewernode_id":"idElement2", "connection_lines":"geometry"}))

# %%
connection_links['fictitious'] = 'true'

# %%
network_conn2.head(2)
# Out:
#   hydronode_id   sewernode_id                    geometry_x     CODEKOPPNT  \
# 0   VL_HN60772  24195613725_1  POINT (49720.629 215107.628)  24195613725_1
# 1   VL_HN60773      7165620_1  POINT (63142.133 172229.301)      7165620_1
#
#                      geometry_y  \
# 0  POINT (49632.228 215175.512)
# 1  POINT (63142.598 172228.907)
#
#                                     connection_lines
# 0  LINESTRING (49720.628540000325 215107.62849998...
# 1  LINESTRING (63142.132540000996 172229.30059998...

# %%
connection_links
# Out:
#       idElement1     idElement2  \
# 0     VL_HN60772  24195613725_1
# 1     VL_HN60773      7165620_1
# 2     VL_HN60774      7166026_1
# 3     VL_HN60775      7165606_1
# 4     VL_HN60776      7165608_1
# ...          ...            ...
# 8984  VL_HN69756      6002935_1
# 8985  VL_HN69757      7184778_1
# 8986  VL_HN69758      7177561_1
# 8987  VL_HN69759      6003589_1
# 8988  VL_HN69760      7169137_1
#
#                                                geometry  \
# 0     LINESTRING (3828319.268 3148978.328, 3828236.4...
# 1     LINESTRING (3838398.511 3105159.856, 3838398.9...
# 2     LINESTRING (3836511.918 3105203.709, 3836511.9...
# 3     LINESTRING (3841436.874 3107664.237, 3841433.5...
# 4     LINESTRING (3841582.291 3107649.537, 3841584.0...
# ...                                                 ...
# 8984  LINESTRING (3996915.723 3101525.462, 3996912.2...
# 8985  LINESTRING (3994360.101 3110453.353, 3994357.9...
# 8986  LINESTRING (4000010.552 3104566.229, 3999720.3...
# 8987  LINESTRING (3993351.027 3104426.881, 3993350.6...
# 8988  LINESTRING (3988936.478 3120555.843, 3988945.0...
#
#                                   UUID watercourse_namespace fictitious
# 0     21fb95a073a34a7f908a86cd98f427b0      gopeg.eu/tracing       true
# 1     a793a461705e452b860a1bbfd621486a      gopeg.eu/tracing       true
# 2     ddb70f0455c34637bb5bfe0c10e52e23      gopeg.eu/tracing       true
# 3     1495042cda824d39bbb9a1a7093571ab      gopeg.eu/tracing       true
# 4     e445c17c3a2d415a81c94251fc5b53aa      gopeg.eu/tracing       true
# ...                                ...                   ...        ...
# 8984  af1e590ce89f4140be7e619ab8f8aeb1      gopeg.eu/tracing       true
# 8985  c6505f3dabf541c9b5af5e33048eeaf8      gopeg.eu/tracing       true
# 8986  01ab346468244f8ca8e0ca00e6394bcf      gopeg.eu/tracing       true
# 8987  1d2143bd618e4a69987891f5a999f2bf      gopeg.eu/tracing       true
# 8988  4ed72ce2c18d414eb92d4c296355a532      gopeg.eu/tracing       true
#
# [8989 rows x 6 columns]

# %%
import uuid
connection_links['UUID'] = [uuid.uuid4().hex for _ in range(len(connection_links.index))]
connection_links['watercourse_namespace'] = "gopeg.eu/tracing"

FINAL_CRS = 'EPSG:3035'
connection_links = connection_links.set_crs(PROJ_CRS)
# connection_links = connection_links.to_crs(FINAL_CRS)

# %%
connection_links
# Out:
#       idElement1     idElement2  \
# 0     VL_HN60772  24195613725_1
# 1     VL_HN60773      7165620_1
# 2     VL_HN60774      7166026_1
# 3     VL_HN60775      7165606_1
# 4     VL_HN60776      7165608_1
# ...          ...            ...
# 8984  VL_HN69756      6002935_1
# 8985  VL_HN69757      7184778_1
# 8986  VL_HN69758      7177561_1
# 8987  VL_HN69759      6003589_1
# 8988  VL_HN69760      7169137_1
#
#                                                geometry  \
# 0     LINESTRING (3828319.268 3148978.328, 3828236.4...
# 1     LINESTRING (3838398.511 3105159.856, 3838398.9...
# 2     LINESTRING (3836511.918 3105203.709, 3836511.9...
# 3     LINESTRING (3841436.874 3107664.237, 3841433.5...
# 4     LINESTRING (3841582.291 3107649.537, 3841584.0...
# ...                                                 ...
# 8984  LINESTRING (3996915.723 3101525.462, 3996912.2...
# 8985  LINESTRING (3994360.101 3110453.353, 3994357.9...
# 8986  LINESTRING (4000010.552 3104566.229, 3999720.3...
# 8987  LINESTRING (3993351.027 3104426.881, 3993350.6...
# 8988  LINESTRING (3988936.478 3120555.843, 3988945.0...
#
#                                   UUID watercourse_namespace fictitious
# 0     21fb95a073a34a7f908a86cd98f427b0      gopeg.eu/tracing       true
# 1     a793a461705e452b860a1bbfd621486a      gopeg.eu/tracing       true
# 2     ddb70f0455c34637bb5bfe0c10e52e23      gopeg.eu/tracing       true
# 3     1495042cda824d39bbb9a1a7093571ab      gopeg.eu/tracing       true
# 4     e445c17c3a2d415a81c94251fc5b53aa      gopeg.eu/tracing       true
# ...                                ...                   ...        ...
# 8984  af1e590ce89f4140be7e619ab8f8aeb1      gopeg.eu/tracing       true
# 8985  c6505f3dabf541c9b5af5e33048eeaf8      gopeg.eu/tracing       true
# 8986  01ab346468244f8ca8e0ca00e6394bcf      gopeg.eu/tracing       true
# 8987  1d2143bd618e4a69987891f5a999f2bf      gopeg.eu/tracing       true
# 8988  4ed72ce2c18d414eb92d4c296355a532      gopeg.eu/tracing       true
#
# [8989 rows x 6 columns]

# %%
connection_links = connection_links.to_crs(PROJ_CRS)

# %%
# connection_links.to_file(config.data_dest / "vl_HS_connection.shp")
# Out:
# C:\Users\u0119822\AppData\Local\Temp\ipykernel_23076\3950933011.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   connection_links.to_file(config.data_dest / "vl_HS_connection.shp")
