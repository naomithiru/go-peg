# %%
from ipyleaflet import GeoJSON, basemaps, Map
import json
import geopandas as gpd

# %%
data = json.load(open(r'C:\Workdir\Develop\GOPEG\tracing\json\response_1667489946178.geojson'))

# %%
geojs = gpd.read_file(r'C:\Workdir\Develop\GOPEG\tracing\json\response_1667489946178.json')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: C:\Workdir\Develop\GOPEG\tracing\json\response_1667489946178.json: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# c:\Workdir\Develop\GOPEG\preprocessing\notebooks\tracing_result.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Workdir/Develop/GOPEG/preprocessing/notebooks/tracing_result.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> geojs = gpd.read_file(r'C:\Workdir\Develop\GOPEG\tracing\json\response_1667489946178.json')
#
# ...

# %%
geojs =

# %%
data
# Out:
# {'warnings': [],
#  'graph': {'vertices': [{'data': {'type': 'Feature',
#      'geometry': {'type': 'Point',
#       'coordinates': [3999688.4031, 3080137.7154]},
#      'properties': {'hydroId': 'VL17342', 'appurtenance_id': ''},
#      'id': 'Tracing_HydroNode.17342'},
#     'distance': None,
#     'in': [],
#     'id': 'vl_waternetwork:VL17342',
#     'out': ['vl_waternetwork:7075418']},
#    {'data': {'type': 'Feature',
#      'geometry': {'type': 'Point',
#       'coordinates': [3999671.4034, 3080448.9501]},
#      'properties': {'appurtenance_id': ''},
#      'id': 'Tracing_HydroNode.47504'},
#     'distance': 324.6931372849933,
#     'in': ['vl_waternetwork:7075418'],
#     'id': 'vl_waternetwork:VL47504',
#     'out': ['vl_waternetwork:7075419']},
#    {'data': {'type': 'Feature',
#      'geometry': {'type': 'Point',
#       'coordinates': [3999677.9192, 3080459.5931]},
#      'properties': {'appurtenance_id': ''},
#      'id': 'Tracing_HydroNode.26754'},
# ...

# %%
centre=[5.4, 50.7]

m = Map(basemap=basemaps.Esri.WorldImagery, center=centre, zoom=5)
m
# Out:
# Map(center=[5.4, 50.7], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_…
